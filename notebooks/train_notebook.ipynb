# %%
# !pip -q install gdown
# !pip -q install py7zr
# !pip -q install datasets evaluate transformers[sentencepiece] librosa jiwer
# !pip install accelerate -Uq
# !pip install bangla-python
# !pip install collection
# !pip install openpyxl
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 688.6 kB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.8/413.8 kB 24.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.9/138.9 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.1/93.1 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 40.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 35.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 2.5 MB/s eta 0:00:00
# Collecting bangla-python
#   Downloading bangla_python-1.9-py3-none-any.whl (10 kB)
# Installing collected packages: bangla-python
# Successfully installed bangla-python-1.9
# Collecting collection
#   Downloading collection-0.1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: collection
#   Building wheel for collection (setup.py) ... done
#   Created wheel for collection: filename=collection-0.1.6-py3-none-any.whl size=5099 sha256=ae84cd0bee98503f60b932ec0684ec9f4660c2cc19ea43bc80cbc18f4c4d9956
#   Stored in directory: /root/.cache/pip/wheels/a5/70/eb/1d28795e9384ab3b9be6359bdde9e1652f6e7dab9d26844f70
# Successfully built collection
# Installing collected packages: collection
# Successfully installed collection-0.1.6
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)

# %%
# !gdown 1EkNql3Vf_AJsjlJe8iX2ZZiUZSx-qWYh   #text. unzip
# !gdown 1X_hnB3CDorqYrRc4gbOKg2be_dLPHiOg   #voice. zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EkNql3Vf_AJsjlJe8iX2ZZiUZSx-qWYh
# To: /content/ASR text.xlsx
# 100% 164k/164k [00:00<00:00, 96.7MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1X_hnB3CDorqYrRc4gbOKg2be_dLPHiOg
# From (redirected): https://drive.google.com/uc?id=1X_hnB3CDorqYrRc4gbOKg2be_dLPHiOg&confirm=t&uuid=e00011a1-b590-4d2e-b66a-599b16179599
# To: /content/Speech.7z
# 100% 2.22G/2.22G [00:32<00:00, 68.5MB/s]

# %%
# !py7zr x 'Speech.7z'

# %%
# !rm 'ASR text.7z'
# !rm 'Speech.7z'

# %%
import os
import librosa
import random
import torch
import evaluate
import torchaudio
import numpy as np
import pandas as pd
import bn
import copy
from collections import Counter
from datasets import Dataset
from dataclasses import dataclass
from typing import Any, Dict, List, Union
from transformers import Seq2SeqTrainingArguments
from transformers import Seq2SeqTrainer
from transformers import WhisperTokenizer
from transformers import WhisperProcessor
from transformers import WhisperFeatureExtractor
from transformers import WhisperForConditionalGeneration

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
df = pd.read_excel('ASR text.xlsx')
df.head()
# Out:
#                   id                                               Text
# 0  Recordign (1).wav  আমার মায়ের জন্য medicine বাবদ প্রতি মাসে almos...
# 1  Recordign (2).wav  স্যারের কথার summary হল- মানুষ যখন চলে যায়, তা...
# 2  Recordign (3).wav  lab এ সকল ল্যাব member দের মধ্যে দায়িত্ব সবসময়...
# 3  Recordign (4).wav  ছবিতে দেখা যাচ্ছে আমরা দুইজন ল্যাবের কাজে busy...
# 4  Recordign (5).wav  ল্যাবের দুইজনকে always আল্লাহর কাছে দুয়া প্রার...

# %%
df['id'] = df['id'].replace('Recordign', 'Recording', regex=True)

# %%
mp3_path = "Speech"

#train_csv = "ASRtext_csv"
#val_tsv = "./dataset/dev.tsv"

# %%
from sklearn.model_selection import train_test_split
#df = pd.read_csv(train_csv)
X_train, X_val, y_train, y_val = train_test_split(df[['id']], df['Text'], test_size=0.2, random_state=42)

# %%
len(X_train), len(y_train)
# Out:
# (1280, 1280)

# %%
len(X_val), len(y_val)
# Out:
# (320, 320)

# %% [markdown]
# **Train**

# %%
train_xlxs = pd.concat([X_train, y_train], axis=1)
train_xlxs.head()
# Out:
#                         id                                               Text
# 1532  Recording (1533).wav  NEVER IN DOUBT. Batted all the way with the ta...
# 628    Recording (629).wav  তিনি আল-জাজিরাকে বলেন, ‘৯ হাজার ৫০০ কোটি ডলারে...
# 693    Recording (694).wav  অবশ্য এখন সংখ্যাটি আরও বেড়েছে। অধিভুক্ত colleg...
# 705    Recording (706).wav  কেন্দ্রীয় স্বরাষ্ট্র প্রতিমন্ত্রী নিত্যানন্দ র...
# 497    Recording (498).wav  এ ক্ষেত্রে তাঁরা হামাসের অতীতের বক্তৃতা–বয়ানের...

# %%
#convert train_xlxs to train_csv

train_xlxs.to_csv('train_csv', index=True)

# %%
#Load train_csv format
train_csv = pd.read_csv('train_csv')
train_csv.head()
# Out:
#    Unnamed: 0                    id  \
# 0        1532  Recording (1533).wav
# 1         628   Recording (629).wav
# 2         693   Recording (694).wav
# 3         705   Recording (706).wav
# 4         497   Recording (498).wav
#
#                                                 Text
# 0  NEVER IN DOUBT. Batted all the way with the ta...
# 1  তিনি আল-জাজিরাকে বলেন, ‘৯ হাজার ৫০০ কোটি ডলারে...
# 2  অবশ্য এখন সংখ্যাটি আরও বেড়েছে। অধিভুক্ত colleg...
# 3  কেন্দ্রীয় স্বরাষ্ট্র প্রতিমন্ত্রী নিত্যানন্দ র...
# 4  এ ক্ষেত্রে তাঁরা হামাসের অতীতের বক্তৃতা–বয়ানের...

# %%
all_tokens=[]
for text in train_csv['Text']:
  tokens = text.split()
  all_tokens.append(tokens)
print(all_tokens)
# Out:
# [['NEVER', 'IN', 'DOUBT.', 'Batted', 'all', 'the', 'way', 'with', 'the', 'tail-enders', 'and', 'took', 'Bangladesh', 'to', 'a', 'very', 'competitive', 'total', 'of', '286', 'runs.'], ['তিনি', 'আল-জাজিরাকে', 'বলেন,', '‘৯', 'হাজার', '৫০০', 'কোটি', 'ডলারের', 'budget,', 'এর', 'মানে', 'হলো', 'যুক্তরাষ্ট্রের', 'কেন্দ্রীয়', 'budget', 'এর', 'পরিমাণ', 'উল্লেখজনক', 'পরিমাণে', 'বেড়েছে।'], ['অবশ্য', 'এখন', 'সংখ্যাটি', 'আরও', 'বেড়েছে।', 'অধিভুক্ত', 'college', 'ও', 'মাদ্রাসার', 'শিক্ষার্থীসহ', 'দেশের', 'সরকারি–বেসরকারি', 'মিলিয়ে', 'বিশ্ববিদ্যালয়গুলোতে', 'total', 'শিক্ষার্থী', '৪৭', 'লাখ', '৫৬', 'হাজার', '৭৪৭', 'জন।'], ['কেন্দ্রীয়', 'স্বরাষ্ট্র', 'প্রতিমন্ত্রী', 'নিত্যানন্দ', 'রাই।', 'বৈঠকে', 'ফসলের', 'minimum', 'সহায়ক', 'মূল্য', 'বা', 'এমএসপির', 'সঙ্গে', 'কেন্দ্রীয়', 'সরকার', 'শস্য', 'বৈচিত্র্যকে', 'জুড়ে', 'দেওয়ার', 'proposal', 'দেন।'], ['এ', 'ক্ষেত্রে', 'তাঁরা', 'হামাসের', 'অতীতের', 'বক্তৃতা–বয়ানের', 'উদ্ধৃতি', 'দিচ্ছেন।', 'America', 'এর', 'প্রতিনিধি', 'পরিষদের', 'আইনপ্রণেতারা', 'স্লোগানটিকে', '‘ইহুদিবিদ্বেষী’', 'অভিহিত', 'করে', 'আইন', 'প্রণয়ন', 'করেছেন।'], ['অনেকেই', 'দেখলাম', 'GRE', 'RC', 'Section', 'নিয়ে', 'চিন্তিত,', 'মনে', 'রাখবেন,', 'রেগুলার', 'প্রাকটিস', 'ব্যতীত', 'RC', 'section', 'এ', 'improve', 'করা', 'একপ্রকার', 'impossible', 'ব্যাপার।'], ['এমন', 'যুক্তি', 'দিয়ে', 'তিনি', 'press', 'conference', 'এ', 'বলেন,', '‘৩০', 'বছর', 'ধরে', 'আমি', 'একই', 'অবস্থান', 'ধরে', 'রেখেছি।', 'আমি', 'খুব', 'easy', 'কথাই', 'বলছি।’'], ['some', 'will', 'understand', 'and', 'work', 'on', 'their', 'weaknesses.', 'We', 'hope', 'Litton', 'Das', 'will', 'take', 'it', 'on', 'a', 'positive', 'note', 'and', 'come', 'back', 'stronger', 'than', 'ever', 'in', 'the', 'ODI', 'side.'], ['পাঞ্জাব,', 'হরিয়ানা', 'ও', 'উত্তর', 'প্রদেশের', 'পশ্চিমাঞ্চলের', 'ধান,', 'গম', 'ও', 'আখ', 'চাষের', 'কারণে', 'কৃষিজমির', 'জলস্তর', 'rapidly', 'কমে', 'যাচ্ছে।'], ['congressional', 'কমিটির', 'নেতাদের', 'অনুমোদন', 'পেতে', 'হবে।', 'সে', 'ক্ষেত্রে', 'details', 'এই', 'proposal', 'এ', 'change', 'আনা', 'হতে', 'পারে।'], ['বাকি', 'সব', 'engineer', 'দের', 'কাজে', 'technology', 'এর', 'ব্যবহার', 'বাড়লেও', 'civil', 'engineer', ',', 'mechanical', ',', 'chemical,', 'marine', 'engineer', 'এসব', 'subject', 'এর', 'demand', 'এখনকার', 'দিনের', 'মতো', 'রয়ে', 'যাবে।'], ['সে', 'অনেক', 'try', 'করলো।', 'email,', 'phone,', 'job', 'site', ',', 'apply,', 'meeting', 'set,', 'অনেক', 'কিছু', 'করলো।', 'কিন্তু', 'কাজ', 'হলো', 'না।'], ['opportunity', 'grap', 'করে', 'না।', 'তাদের', 'চাকরি', 'খেয়ে', 'দেয়।', 'আর', 'যারা', 'adapt', 'করে,', 'তারা', 'আগের', 'চাইতে', 'দুই-তিনগুণ', 'ভালো', 'করবে।', 'যেমন', 'ChatGPT', 'এর', 'কারণে', 'job', 'কিন্তু', 'কমে', 'নাই।', 'বরং', 'ChatGPT', 'দিয়ে', 'সফটওয়্যার', 'বানানোর', 'জব', 'বাড়ছে'], ['প্রায়', '৩', 'হাজার', '৩০০', 'বিভিন্ন', 'রকম', 'কোষ', 'রয়েছে', 'মানুষের', 'মস্তিষ্কে।', 'এত', 'দিন', 'এ', 'বিষয়ে', 'বিস্তারিত', 'তথ্য', 'জানা', 'না', 'থাকলেও', 'এবার', 'মানুষের', 'মস্তিষ্কের', 'largest', 'বা', 'পূর্ণাঙ্গ', 'map', 'প্রকাশ', 'করেছেন', 'গবেষকেরা।'], ['third', 'party', 'tools', 'এর', 'সাথে', 'software', 'integration।', 'একটা', 'software', 'অনেক', 'developer', 'মিলে', 'বানায়।', 'তাই', 'অন্যের', 'code', 'দেখে', 'বুঝার', 'ability', '।'], ['করলে', 'আমি', 'next', 'semester', 'ধরতে', 'পারব', 'না,', 'তুমি', 'একটু', 'কষ্ট', 'করে,', 'টিচারদের', 'কাছ', 'থেকে', 'feedback', 'নাও।', 'শেষমেষ,', '১৭', 'নভেম্বর', '২০১০', 'তারিখে', 'cse', 'department', 'থেকে', 'স্বপ্নের', 'অ্যাডমিশন', 'পেয়ে', 'গেলাম।'], ['Penselvania', 'state', 'এ', 'এক', 'সমাবেশে', 'ট্রাম্পের', 'করা', 'মন্তব্য', 'নিয়ে', 'এর', 'আগে', 'জো', 'বাইডেনের', 'administration', 'ও', 'প্রতিক্রিয়া', 'জানিয়েছে।'], ['কেমন', 'হতো', 'যদি', 'এমন', 'এক', 'পৃথিবীতে', 'বাস', 'করা', 'যেত,', 'যেখানে', 'শহরের', 'কোলাহল', 'বা', 'jam', 'নেই,', 'কাজের', 'ঝামেলা', 'নেই,', 'বনের', 'ভেতরে', 'থাকা', 'ছোট', 'একটি', 'ঘরে', 'কাটিয়ে', 'দেওয়া', 'যেত', 'whole', 'life।'], ['শিক্ষামন্ত্রী', 'বলেন,', 'দেশের', 'শিক্ষাপ্রতিষ্ঠানে', 'যে', 'education', 'system', 'চালু', 'হচ্ছে,', 'ওই', 'শিক্ষাব্যবস্থায়', 'মেধাবী', 'একটি', 'জাতি', 'তৈরি', 'হবে।'], [ ...

# %%
flat_tokens = [word for sublist in all_tokens for word in sublist]  # Optional
word_counts = Counter(flat_tokens)
word_counts
# Out:
# Counter({'NEVER': 2,
#          'IN': 1,
#          'DOUBT.': 1,
#          'Batted': 1,
#          'all': 20,
#          'the': 141,
#          'way': 6,
#          'with': 15,
#          'tail-enders': 1,
#          'and': 91,
#          'took': 1,
#          'Bangladesh': 20,
#          'to': 74,
#          'a': 55,
#          'very': 15,
#          'competitive': 2,
#          'total': 2,
#          'of': 56,
#          '286': 1,
#          'runs.': 1,
#          'তিনি': 67,
#          'আল-জাজিরাকে': 1,
#          'বলেন,': 53,
#          '‘৯': 1,
#          'হাজার': 32,
#          '৫০০': 2,
#          'কোটি': 12,
#          'ডলারের': 4,
#          'budget,': 1,
#          'এর': 407,
#          'মানে': 5,
#          'হলো': 19,
#          'যুক্তরাষ্ট্রের': 33,
#          'কেন্দ্রীয়': 10,
#          'budget': 1,
#          'পরিমাণ': 5,
#          'উল্লেখজনক': 1,
#          'পরিমাণে': 2,
#          'বেড়েছে।': 6,
#          'অবশ্য': 6,
#          'এখন': 48,
#          'সংখ্যাটি': 2,
#          'আরও': 36,
#          'অধিভুক্ত': 1,
#          'college': 4,
#          'ও': 221,
#          'মাদ্রাসার': 1,
#          'শিক্ষার্থীসহ': 1,
#          'দেশের': 27,
#          'সরকারি–বেসরকারি': 1,
#          'মিলিয়ে': 8,
#          'বিশ্ববিদ্যালয়গুলোতে': 3,
#          'শিক্ষার্থী': 11,
#          '৪৭': 3,
#          'লাখ': 14,
#          '৫৬': 1,
#          '৭৪৭': 1,
#          'জন।': 3,
#          'স্বরাষ্ট্র': 1,
#          'প্রতিমন্ত্রী': 2,
#          'নিত্যানন্দ': 1,
#          'রাই।': 1,
#          'বৈঠকে': 4,
#          'ফসলের': 2,
#          'minimum': 2,
#          'সহায়ক': 5,
#          'মূল্য': 5,
#          'বা': 113,
#          'এমএসপির': 2,
#          'সঙ্গে': 73,
#          'সরকার': 8,
#          'শস্য': 1,
#          'বৈচিত্র্যকে': 1,
#          'জুড়ে': 1,
#          'দেওয়ার': 8,
#          'proposal': 8,
#          'দেন।': 10,
#          'এ': 415,
#          'ক্ষেত্রে': 15,
#          'তাঁরা': 18,
#          'হামাসের': 6,
#          'অতীতের': 1,
#          'বক্তৃতা–বয়ানের': 1,
#          'উদ্ধৃতি': 1,
#          'দিচ্ছেন।': 3,
#          'America': 2,
#          'প্রতিনিধি': 6,
#          'পরিষদের': 6,
#          'আইনপ্রণেতারা': 1,
#          'স্লোগানটিকে': 1,
#          '‘ইহুদিবিদ্বেষী’': 1,
#          'অভিহিত': 1,
#          'করে': 230,
#          'আইন': 1,
#          'প্রণয়ন': 1,
#          'করেছেন।': 16,
#          'অনেকেই': 11,
#          'দেখলাম': 6,
#          'GRE': 25,
#          'RC': 3,
#          'Section': 2,
#          'নিয়ে': 87,
#          'চিন্তিত,': 1,
#          'মনে': 48,
#          'রাখবেন,': 1,
#          'রেগুলার': 3,
#          'প্রাকটিস': 3,
#          'ব্যতীত': 1,
#          'section': 2,
#          'improve': 2,
#          'করা': 137,
#          'একপ্রকার': 1,
#          'impossible': 2,
#          'ব্যাপার।': 1,
#          'এমন': 42,
#          'যুক্তি': 3,
#          'দিয়ে': 73,
#          'press': 2,
#          'conference': 6,
#          '‘৩০': 1,
#          'বছর': 41,
#          'ধরে': 34,
#          'আমি': 84,
#          'একই': 16,
#          'অবস্থান': 5,
#          'রেখেছি।': 2,
#          'খুব': 19,
#          'easy': 5,
#          'কথাই': 2,
#          'বলছি।’': 1,
#          'some': 9,
#          'will': 24,
#          'understand': 2,
#          'work': 7,
#          'on': 26,
#          'their': 3,
#          'weaknesses.': 1,
#          'We': 2,
#          'hope': 2,
#          'Litton': 5,
#          'Das': 2,
#          'take': 3,
#          'it': 21,
#          'positive': 1,
#          'note': 1,
#          'come': 3,
#          'back': 6,
#          'stronger': 2,
#          'than': 2,
#          'ever': 1,
#          'in': 78,
#          'ODI': 2,
#          'side.': 3,
#          'পাঞ্জাব,': 1,
#          'হরিয়ানা': 1,
#          'উত্তর': 4,
#          'প্রদেশের': 1,
#          'পশ্চিমাঞ্চলের': 1,
#          'ধান,': 2,
#          'গম': 1,
#          'আখ': 1,
#          'চাষের': 1,
#          'কারণে': 26,
#          'কৃষিজমির': 1,
#          'জলস্তর': 2,
#          'rapidly': 1,
#          'কমে': 8,
#          'যাচ্ছে।': 9,
#          'congressional': 2,
#          'কমিটির': 3,
#          'নেতাদের': 4,
#          'অনুমোদন': 3,
#          'পেতে': 12,
#          'হবে।': 111,
#          'সে': 48,
#          'details': 4,
#          'এই': 147,
#          'change': 13,
#          'আনা': 8,
#          'হতে': 37,
#          'পারে।': 34,
#          'বাকি': 10,
#          'সব': 48,
#          'engineer': 5,
#          'দের': 36,
#          'কাজে': 25,
#          'technology': 15,
#          'ব্যবহার': 31,
#          'বাড়লেও': 1,
#          'civil': 1,
#          ',': 62,
#          'mechanical': 1,
#          'chemical,': 1,
#          'marine': 1,
#          'এসব': 25,
#          'subject': 9,
#          'demand': 19,
#          'এখনকার': 4,
#          'দিনের': 17,
#          'মতো': 49,
#          'রয়ে': 1,
#          'যাবে।': 50,
#          'অনেক': 55,
#          'try': 10,
#          'করলো।': 2,
#          'email,': 1,
#          'phone,': 1,
#          'job': 15,
#          'site': 2,
#          'apply,': 1,
#          'meeting': 4,
#          'set,': 1,
#          'কিছু': 52,
#          'কিন্তু': 62,
#          'কাজ': 82,
#          'না।': 149,
#          'opportunity': 1,
#          'grap': 1,
#          'তাদের': 36,
#          'চাকরি': 7,
#          'খেয়ে': 4,
#          'দেয়।': 14,
#          'আর': 107,
#          'যারা': 17,
#          'adapt': 1,
#          'করে,': 9,
#          'তারা': 21,
#          'আগের': 12,
#          'চাইতে': 5,
#          'দুই-তিনগুণ': 1,
#          'ভালো': 47,
#          'করবে।': 27,
#          'যেমন': 18,
#          'ChatGPT': 3,
#          'নাই।': 23,
#          'বরং': 20,
#          'সফটওয়্যার': 2,
#          'বানানোর': 3,
#          'জব': 13,
#          'বাড়ছে': 3,
#          'প্রায়': 15,
#          '৩': 14,
#          '৩০০': 2,
#          'বিভিন্ন': 59,
#          'রকম': 6,
#          'কোষ': 6,
#          'রয়েছে': 12,
#          'মানুষের': 16,
#          'মস্তিষ্কে।': 1,
#          'এত': 12,
#          'দিন': 29,
#          'বিষয়ে': 39,
#          'বিস্তারিত': 9,
#          'তথ্য': 48,
#          'জানা': 19,
#          'না': 102,
#          'থাকলেও': 5,
#          'এবার': 20,
#          'মস্তিষ্কের': 10,
#          'largest': 2,
#          'পূর্ণাঙ্গ': 2,
#          'map': 4,
#          'প্রকাশ': 16,
#          'করেছেন': 14,
#          'গবেষকেরা।': 2,
#          'third': 3,
#          'party': 2,
#          'tools': 2,
#          'সাথে': 29,
#          'software': 17,
#          'integration।': 1,
#          'একটা': 76,
#          'developer': 8,
#          'মিলে': 7,
#          'বানায়।': 1,
#          'তাই': 48,
#          'অন্যের': 1,
#          'code': 12,
#          'দেখে': 18,
#          'বুঝার': 4,
#          'ability': 5,
#          '।': 35,
#          'করলে': 21,
#          'next': 9,
#          'semester': 2,
#          'ধরতে': 1,
#          'পারব': 3,
#          'না,': 20,
#          'তুমি': 15,
#          'একটু': 15,
#          'কষ্ট': 1,
#          'টিচারদের': 1,
#          'কাছ': 6,
#          'থেকে': 167,
#          'feedback': 3,
#          'নাও।': 1,
#          'শেষমেষ,': 1,
#          '১৭': 4,
#          'নভেম্বর': 2,
#          '২০১০': 1,
#          'তারিখে': 2,
#          'cse': 3,
#          'department': 9,
#          'স্বপ্নের': 2,
#          'অ্যাডমিশন': 1,
#          'পেয়ে': 9,
#          'গেলাম।': 4,
#          'Penselvania': 1,
#          'state': 9,
#          'এক': 74,
#          'সমাবেশে': 2,
#          'ট্রাম্পের': 7,
#          'মন্তব্য': 3,
#          'আগে': 47,
#          'জো': 7,
#          'বাইডেনের': 5,
#          'administration': 3,
#          'প্রতিক্রিয়া': 1,
#          'জানিয়েছে।': 3,
#          'কেমন': 4,
#          'হতো': 5,
#          'যদি': 29,
#          'পৃথিবীতে': 2,
#          'বাস': 4,
#          'যেত,': 1,
#          'যেখানে': 2,
#          'শহরের': 4,
#          'কোলাহল': 1,
#          'jam': 1,
#          'নেই,': 5,
#          'কাজের': 18,
#          'ঝামেলা': 2,
#          'বনের': 2,
#          'ভেতরে': 3,
#          'থাকা': 51,
#          'ছোট': 12,
#          'একটি': 82,
#          'ঘরে': 2,
#          'কাটিয়ে': 3,
#          'দেওয়া': 42,
#          'যেত': 2,
#          'whole': 4,
#          'life।': 1,
#          'শিক্ষামন্ত্রী': 8,
#          'শিক্ষাপ্রতিষ্ঠানে': 1,
#          'যে': 61,
#          'education': 3,
#          'system': 16,
#          'চালু': 37,
#          'হচ্ছে,': 7,
#          'ওই': 23,
#          'শিক্ষাব্যবস্থায়': 2,
#          'মেধাবী': 1,
#          'জাতি': 4,
#          'তৈরি': 52,
#          'মিনিমাম': 1,
#          'ছয়': 10,
#          'মাস': 14,
#          'একবছর': 2,
#          'সুপার': 2,
#          'সিরিয়াস': 3,
#          'স্কিল': 5,
#          'প্রাথমিক': 4,
#          'লেভেল': 2,
#          'ডেভেলপ': 4,
#          'করে।': 36,
#          'পোর্টফোলিও': 1,
#          'বিল্ড': 1,
#          'করো।': 6,
#          'সেটা': 57,
#          'অন্য': 54,
#          'প্রফেশনালদের': 1,
#          'শেয়ার': 4,
#          'করা।': 18,
#          'লেভেলে': 1,
#          'পৌঁছানোর': 3,
#          'পর': 72,
#          'নেটওয়ার্কিং': 1,
#          'Emon': 3,
#          'rarely': 1,
#          'gets': 1,
#          'opportunities': 1,
#          'play': 8,
#          'games': 2,
#          'any': 6,
#          'platform': 3,
#          'most': 3,
#          'cases,': 1,
#          'he': 18,
#          'didn’t': 3,
#          'deserve': 3,
#          'sit': 1,
#          'bench': 2,
#          'অর্থাৎ': 8,
#          'professional': 3,
#          'life': 9,
#          'প্রবেশ': 9,
#          'ভার্সিটিতে': 2,
#          'যা': 22,
#          'শিখে': 4,
#          'আসছো': 2,
#          'তার': 43,
#          'বেশি': 56,
#          'জিনিস': 12,
#          'শিখতে': 9,
#          'communication': 3,
#          'skill,': 1,
#          'use': 13,
#          'করার': 80,
#          'গড়ে': 5,
#          'তুলতে': 3,
#          'pump': 2,
#          'নষ্টও': 1,
#          'ফেলছিলাম।': 1,
#          'পরে': 38,
#          'নতুন': 62,
#          'কিনে': 8,
#          'ঠিক': 19,
#          'লাগছে।': 1,
#          'বাসা': 5,
#          'বাড়ির': 4,
#          'পারলেও': 1,
#          'ইউটিউব': 5,
#          'পাকনামি': 1,
#          'করতে': 198,
#          'যাই।': 3,
#          'ম্যাকস্লিপি': 2,
#          'অস্ত্রোপচারের': 2,
#          'কাজটা': 4,
#          'সুচারু': 1,
#          'জন্য': 148,
#          'ছিল': 47,
#          'ভিঞ্চির': 1,
#          'যোগ্য': 2,
#          'assistant।': 2,
#          'রোবট': 1,
#          'অস্ত্রোপচারে': 2,
#          'সফলতার': 1,
#          'দ্য': 2,
#          'ভিঞ্চি': 2,
#          'ম্যাকস্লিপিকে': 1,
#          'জুটি': 4,
#          'অস্ত্রোপচার': 3,
#          'complete': 2,
#          'হয়।': 54,
#          '28': 1,
#          'February': 2,
#          'রেজাল্ট': 1,
#          'হবে': 33,
#          'এবং': 88,
#          '১': 14,
#          'মার্চ': 3,
#          'ক্লাস': 3,
#          'শুরু': 43,
#          'হবে।রেজিস্ট্রেশন': 1,
#          'করুন': 3,
#          'লিংকে': 1,
#          '&': 7,
#          'IELTS': 4,
#          'Prep': 3,
#          'BD”': 2,
#          'গ্রুপ': 3,
#          '-এ': 3,
#          'জয়েন': 1,
#          'করুন,': 4,
#          'অনেকে': 4,
#          'স্টক': 3,
#          'মার্কেটে': 1,
#          'বিনিয়োগ': 4,
#          'করছেন।': 9,
#          'ফলে': 39,
#          'চলতি': 5,
#          'জাপানের': 1,
#          'মার্কেটের': 1,
#          'সবচেয়ে': 15,
#          'সূচক': 1,
#          'বেড়েছে': 3,
#          'তুরস্কের': 7,
#          'মার্কেটের।': 1,
#          'England': 2,
#          'South': 3,
#          'Africa': 2,
#          'অস্ট্রেলিয়া,': 1,
#          'আয়ারল্যান্ড': 1,
#          'যুক্তরাষ্ট্রেও': 1,
#          'প্রকল্প': 7,
#          'চালানো': 4,
#          'হয়েছে।': 50,
#          'পাঁচ': 8,
#          'শতাধিক': 1,
#          'প্রতিষ্ঠান': 13,
#          'প্রকল্পে': 3,
#          'participate': 3,
#          'করেছে।': 16,
#          'করেন,': 13,
#          'পানিতে': 2,
#          'পড়ে': 19,
#          'গেলে': 12,
#          'দ্রুত': 14,
#          'চালের': 3,
#          'মধ্যে': 67,
#          'রেখে': 9,
#          'phone': 14,
#          'set': 5,
#          'টি': 21,
#          'বাঁচানো': 1,
#          'internet': 6,
#          'ভূরি': 1,
#          'ভূরি।আসল': 1,
#          'সত্যিটা': 1,
#          'যাক।': 3,
#          'চাল': 1,
#          'জলীয়': 1,
#          'পদার্থ': 2,
#          'absorb': 1,
#          'এটা': 17,
#          'ঠিক।': 1,
#          'নদী': 4,
#          'সমুদ্র': 1,
#          'পর্যন্ত’': 1,
#          'শব্দবন্ধ': 2,
#          'ইসরায়েল': 2,
#          'যুক্তরাষ্ট্র': 4,
#          'দুই': 50,
#          'দেশেই': 1,
#          'debate': 1,
#          'জন্ম': 3,
#          'দিয়েছে।': 1,
#          'দেশ': 10,
#          'দুটিতে': 1,
#          'ফিলিস্তিনিপন্থী': 1,
#          'বিক্ষোভকারীরা': 1,
#          'বিশেষ': 15,
#          'Positive': 1,
#          'Test,': 3,
#          'Negative': 1,
#          'Boundary': 1,
#          'Corner': 1,
#          'Case,': 1,
#          'এইগুলা': 5,
#          'সম্পর্কে': 11,
#          'ধারণা': 13,
#          'নিবে।': 2,
#          'coverage': 1,
#          'বের': 30,
#          'পারলে': 5,
#          'খুবই': 14,
#          'ভালো।': 5,
#          'The': 11,
#          'tail-ender': 3,
#          'is': 40,
#          'not': 12,
#          'exposed': 1,
#          'yet.': 1,
#          'Such': 2,
#          'commentary': 1,
#          'international': 11,
#          'level': 6,
#          'embarrassing': 1,
#          'level.': 1,
#          'রাইখো--': 1,
#          'ডেডলাইন': 4,
#          'ইজ': 2,
#          'ডেডলাইন।': 1,
#          '২০২৪': 3,
#          '২০২৪।': 1,
#          'লাইফে': 1,
#          'একবারই': 1,
#          'আসবে।': 3,
#          'টিউটোরিয়াল': 1,
#          'পারি।': 1,
#          'নিজে': 17,
#          'প্রজেক্ট': 4,
#          'কোন': 37,
#          'আলাদা': 4,
#          'দিলে': 10,
#          'পারিনা।': 1,
#          'জাতিসংঘের': 7,
#          'নিরাপত্তা': 11,
#          'পরিষদে': 6,
#          'আলজেরিয়া': 2,
#          'অবিলম্বে': 4,
#          'যুদ্ধবিরতির': 5,
#          'প্রস্তাব': 7,
#          'এনেছিল': 1,
#          'আলজেরিয়া।': 1,
#          'শব্দটির': 1,
#          'আপত্তি': 1,
#          'জানায়': 1,
#          'ক্যারিয়ার': 1,
#          'গঠনের': 3,
#          'পাশাপাশি': 35,
#          'economics': 1,
#          'আবদান': 1,
#          'রাখেন': 1,
#          'তাঁরা।': 8,
#          'বিষয়ে': 2,
#          'higher': 1,
#          'studies': 2,
#          'প্রতিবছর': 3,
#          'বাংলাদেশ': 21,
#          'উল্লেখযোগ্যসংখ্যক': 1,
#          'বিদেশে': 3,
#          'পাড়ি': 1,
#          'যেসব': 11,
#          'আরব': 12,
#          'family': 6,
#          'বেড়ে': 8,
#          'উঠেছি,': 1,
#          'কখনোই': 3,
#          'খবরে': 4,
#          'কান': 1,
#          'দিতে': 26,
#          'দেখিনি।': 1,
#          '২০০০': 1,
#          'সালে': 15,
#          'বাবা': 1,
#          'পরিবার': 6,
#          'city': 4,
#          'তে': 35,
#          'চলে': 19,
#          'আসেন।': 1,
#          'Devin': 1,
#          'productivity': 4,
#          'পথে': 4,
#          'হাটতেছে': 2,
#          '৫-১০': 1,
#          'বছরে': 5,
#          'ডেভিন,': 1,
#          'কেভিন,': 1,
#          'নবিন': 1,
#          '"মমিন': 1,
#          'AI"': 1,
#          'নামের': 17,
#          'কেউ': 15,
#          'complex': 2,
#          'project': 11,
#          'দেয়া': 12,
#          'অবাক': 2,
#          'হওয়ার': 36,
#          'কিছুই': 6,
#          'থাকবে': 10,
#          'পোলিও': 1,
#          'টিকাদান': 1,
#          'কর্মীদের': 7,
#          'security': 17,
#          'involved': 2,
#          'ছিলেন।': 9,
#          'দেশটির': 9,
#          'employees': 2,
#          'জানিয়েছেন।': 2,
#          'Tree': 1,
#          'related': 6,
#          'algorithm,': 1,
#          'Time': 2,
#          'complexity': 1,
#          'কিভাবে': 13,
#          'object': 2,
#          'oriented': 2,
#          'programming': 13,
#          'principal': 1,
#          'apply': 4,
#          'জানতে': 16,
#          'microsoft': 5,
#          'তথ্যমতে,': 7,
#          'কৃত্রিম': 20,
#          'বুদ্ধিমত্তা': 11,
#          'tool': 24,
#          'email': 24,
#          'লিখে': 5,
#          'ছাড়াও': 6,
#          'অন্যদের': 9,
#          'পাঠানো': 8,
#          'গুরুত্বপূর্ণ': 9,
#          'সংক্ষেপে': 1,
#          'জানাতে': 3,
#          'আকারে': 4,
#          'বড়': 32,
#          'খুলেই': 1,
#          'সেখানে': 17,
#          'পারবেন': 8,
#          'ব্যবহারকারীরা।': 3,
#          'দলের': 14,
#          'আবহটা': 1,
#          'বেশ': 19,
#          'আমরা': 24,
#          'পরের': 19,
#          'ম্যাচের': 1,
#          'মুখিয়ে': 1,
#          'আছি।’': 1,
#          'hopefully': 1,
#          'ম্যাচও': 1,
#          'জিততে': 2,
#          'পারব।': 1,
#          'technical': 1,
#          'podcast': 2,
#          'শুনতে': 2,
#          'পারো।': 4,
#          'সময়': 67,
#          'থাকলে': 16,
#          'open': 2,
#          'source': 4,
#          'contribute': 1,
#          'তবে': 98,
#          'জিনিসগুলো': 4,
#          'শিখব।': 1,
#          'দরকার': 12,
#          'হলে': 28,
#          'আপনি': 11,
#          'test': 6,
#          'নিবেন।': 1,
#          'বদলে': 4,
#          'মাস্টার্সের': 3,
#          'দুইটা': 10,
#          'course': 3,
#          'নিবো।': 2,
#          'বাধ্য': 10,
#          'হয়ে': 75,
#          'পায়ে': 3,
#          'হেঁটেই': 1,
#          'যাওয়া': 14,
#          'আসা': 5,
#          'করতাম।': 3,
#          'প্রতিদিন': 7,
#          'বাসায়': 9,
#          'ফিরে': 5,
#          'bank': 6,
#          'website': 16,
#          'ঢুকে': 4,
#          'দেখতাম।': 2,
#          'কত': 2,
#          'টাকা': 20,
#          'ঢুকেছে।': 1,
#          'AI': 9,
#          'bug': 6,
#          'bounty': 2,
#          'কর্মসূচিতে': 5,
#          'অংশ': 17,
#          'একাধিক': 12,
#          'ত্রুটিও': 1,
#          'শনাক্ত': 5,
#          'ত্রুটি': 6,
#          'শনাক্তের': 1,
#          'research': 13,
#          'centre': 2,
#          'portal': 3,
#          'প্রতিবেদন': 8,
#          'জমা': 3,
#          'এরপর': 30,
#          'ত্রুটিগুলো': 1,
#          'পর্যালোচনা': 5,
#          'সন্ধানদাতাদের': 1,
#          'পুরস্কার': 1,
#          'দেবে': 8,
#          'microsoft।': 3,
#          'পশ্চিমা': 2,
#          'সামরিক': 6,
#          'জোট': 3,
#          'nato': 3,
#          'সদস্যদেশ': 2,
#          'জোটে': 1,
#          'বকেয়া': 1,
#          'paid': 1,
#          'সেসব': 6,
#          'দেশে': 11,
#          'হামলা': 9,
#          'চালাতে': 9,
#          'রাশিয়াকে': 2,
#          'motivate': 1,
#          'করবেন,': 1,
#          'Customers': 1,
#          'আগ্রহ': 5,
#          'দেখাচ্ছেন': 1,
#          'নরম': 2,
#          'কাপড়': 1,
#          'কম': 25,
#          'প্রতি।': 1,
#          'weather': 1,
#          'এটাই': 6,
#          'উপযোগী।': 1,
#          'ঢিলেঢালা': 2,
#          'লম্বা': 5,
#          'কুর্তা,': 1,
#          'টপ': 2,
#          'শার্ট': 1,
#          'ধারায়ও': 1,
#          'চলছে।': 2,
#          'busy': 1,
#          'দিনে': 6,
#          'স্টাইল': 1,
#          'স্বস্তি': 3,
#          'দুটোই': 1,
#          'পাওয়া': 29,
#          'যায়।': 39,
#          'অন্যদিকে': 2,
#          'বাবাজির': 1,
#          'তো': 16,
#          'ছুটি': 4,
#          'লাগবে': 4,
#          '২৪': 6,
#          'ঘন্টা': 2,
#          'সপ্তাহে': 9,
#          '৭': 5,
#          'ডেভিন': 3,
#          'team': 26,
#          'member': 5,
#          'হিসেবে': 39,
#          'জায়গা': 6,
#          'পেলে,': 1,
#          'কারো': 3,
#          'জায়গাতো': 2,
#          'খাবেই।': 1,
#          'এছাড়াও': 2,
#          'পাহাড়ে': 1,
#          'হাইকিং,': 1,
#          'কাঁদায়': 1,
#          'টিম': 6,
#          'মেম্বারের': 1,
#          'যায়,': 11,
#          'চা': 1,
#          'বাগান,': 1,
#          'লেকে': 1,
#          'রিসোর্টে': 1,
#          'স্পোর্টস': 1,
#          'এক্টিভিটি।': 1,
#          'ভোরে': 1,
#          'দৌড়।': 1,
#          'ব্যাডমিন্টনে': 1,
#          'পার্টনারের': 1,
#          'জোরে': 2,
#          'সম্মানজনক': 1,
#          'কৌটায়': 1,
#          'জিতেছি।': 2,
#          'দীর্ঘদিন': 2,
#          'মহাকাশ': 7,
#          'পর্যটন': 1,
#          'launch': 2,
#          'করছে': 16,
#          'মার্কিন': 27,
#          'organization': 8,
#          'ভার্জিন': 5,
#          'গ্যালাক্টিক।': 2,
#          'August': 1,
#          'month': 4,
#          'প্রথমবারের': 7,
#          'পর্যটক': 1,
#          'ভ্রমণে': 1,
#          'যাওয়ার': 14,
#          'ঘোষণা': 11,
#          'দিয়েছেন': 8,
#          'গ্যালাক্টিকের': 1,
#          'প্রতিষ্ঠাতা': 2,
#          'রিচার্ড': 1,
#          'ব্রনসন।': 1,
#          'Although': 2,
#          'Rishad': 3,
#          'no': 6,
#          'where': 3,
#          'near': 2,
#          'Hasaranga’s': 4,
#          'class,': 2,
#          'but': 7,
#          'playing': 6,
#          'Taijul': 3,
#          'over': 15,
#          'him': 6,
#          'this': 20,
#          'flat': 2,
#          'track': 4,
#          'again': 4,
#          'might': 3,
#          'turn': 2,
#          'into': 3,
#          'big': 6,
#          'mistake': 2,
#          'পরদিন': 2,
#          'হিব্রু': 1,
#          'ভাষায়': 5,
#          'বিবৃতিতে': 2,
#          'নেতানিয়াহু': 4,
#          'সমাধান': 4,
#          'ব্যর্থ': 4,
#          'তাঁর': 53,
#          'অতীত': 1,
#          'কর্মকাণ্ডের': 1,
#          'প্রতি': 15,
#          'ইঙ্গিত': 4,
#          'করেন।': 28,
#          'লেখা,': 1,
#          'reply': 2,
#          'দেয়া।': 2,
#          'task': 3,
#          'priority': 3,
#          'বুঝা।': 1,
#          'time': 30,
#          'management': 4,
#          'planning': 1,
#          'মাঝে': 7,
#          'develop': 7,
#          'সেগুলা': 5,
#          'present': 3,
#          'লাগতে': 2,
#          '২০২৭': 1,
#          'ভবঘুরে': 7,
#          'গ্রহদের': 1,
#          'নজরে': 1,
#          'আনতে': 7,
#          'যাত্রা': 11,
#          'করবে': 13,
#          'রোমান': 2,
#          'telescope।': 1,
#          'আপাতত': 2,
#          'scientist': 1,
#          'টেলিস্কোপের': 2,
#          'মাধ্যমে': 28,
#          '৪০০': 1,
#          'গ্রহের': 7,
#          'সন্ধান': 11,
#          'চাহিদা': 3,
#          'এতে': 24,
#          'ক্ষতি': 4,
#          'হচ্ছে': 22,
#          'না;': 2,
#          'কারণ': 27,
#          'চেয়ে': 8,
#          'দরে': 2,
#          'বিক্রি': 3,
#          'কোনো': 68,
#          'সমস্যাই': 1,
#          'সুযোগ': 19,
#          'তোমার': 23,
#          'শেখা': 1,
#          'উচিত।': 2,
#          'চাইলে': 16,
#          'youtube': 9,
#          'খুঁজে': 15,
#          'মেলেক': 2,
#          'আলকেস': 1,
#          'বেতন': 10,
#          'পান,': 3,
#          'তা': 32,
#          'ক্রেডিট': 3,
#          'কার্ডের': 2,
#          'সুদ': 1,
#          'পরিশোধেই': 1,
#          'ব্যয়': 3,
#          'সেই': 55,
#          'কার্ড': 2,
#          'দিয়েই': 5,
#          'মাসের': 7,
#          'কেনাকাটা': 2,
#          'সারেন': 1,
#          'তিনি।': 12,
#          'there': 5,
#          'was': 22,
#          'connection': 3,
#          'ball': 5,
#          'whatsoever.': 2,
#          'DUCK': 2,
#          'for': 46,
#          'Mahmudullah.': 4,
#          'lose': 2,
#          'two': 3,
#          'wickets': 4,
#          'same': 4,
#          'over.': 3,
#          'বিজ্ঞপ্তিতে': 4,
#          'জুয়েলার্স': 2,
#          'সমিতি': 2,
#          'বলছে,': 4,
#          'স্থানীয়': 7,
#          'বাজারে': 10,
#          'খাঁটি': 1,
#          'সোনার': 7,
#          '(পিওর': 1,
#          'গোল্ড)': 1,
#          'দাম': 14,
#          'যাওয়ায়': 4,
#          'সংগতি': 1,
#          'নির্ধারণ': 2,
#          'আগামীকাল': 2,
#          'শুক্রবার': 3,
#          'কার্যকর': 4,
#          'স্ত্রী': 2,
#          'হল-মার্কের': 1,
#          'chairman': 2,
#          'জেসমিন': 4,
#          'ইসলামসহ': 1,
#          '৯': 7,
#          'জনকে': 1,
#          'যাবজ্জীবন': 1,
#          'কারাদণ্ড': 2,
#          'ঢাকার': 2,
#          'জজ': 1,
#          'আদালত-১-এর': 1,
#          'judge': 1,
#          'আবুল': 2,
#          'কাসেম।': 1,
#          'রায়ের': 2,
#          'পর্যবেক্ষণে': 1,
#          ...})

# %%
replace_dict = {'ডলারের': 'dollar এর','মেম্বারের':'member এর',
                'এমএসপির': 'MSP-র','রেগুলার': 'regular','প্রাকটিস':'practise',
                'কমিটি ':'committee-','সফটওয়্যার':'software','রিসোর্টে':'resort এ',
                'নভেম্বর':'november','শার্ট':'shirt','স্পোর্টস':'sports',
                'সুপার':'super','সিরিয়াস':'serious','স্কিল':'skill','লেভেল':'level',
                'ডেভেলপ':'develop','শেয়ার':'share','ভার্সিটি':'versity ','শেয়ার':'share',
                'ইউটিউব':'youtube','স্টাইল':'style',
                'মার্চ':'march','গ্রুপ':'group','স্টক':'stock','হাইকিং':'hiking',
                'মার্কেটের':'market এর','ডেডলাইন':'deadline','এক্টিভিটি':'activity',
                'প্রজেক্ট':'project','ব্যাডমিন্টনে':'badminton এ',
                'ম্যাচ':'match ','মাস্টার্সের':'masters এর','টপ':'top','পার্টনারের':'partner এর',
                'টিম':'team','ভার্জিন':'virgin','রোমান':'roman','গ্যালাক্টিকের':'galactic এর',
                'টেলিস্কোপের':'telescope এর','ক্রেডিট':'credit','পিওর':'pure','গোল্ড':'gold',
                'কার্ডের':'card এর','কার্ড':'card','জুয়েলার্স':'jewellers','ডিস্ট্রাকশনের':'distraction এর',
                'প্লাস':'plus','স্পেসিফিক':'specific','টাইম':'time',
                'ইজি':'easy','ওয়েবসাইটে':'website এ','ক্যারিয়ার':'career','মিডউইকেটে':'midwicket',
                'ওয়েবসাইটের':'website এর','ট্রাম্পকে':'trump কে','আইডিয়া':'idea',
                'ফেব্রুয়ারি':'february','স্টুডেন্ট':'student','পোলিও':'polio','জেনারেশনের':'generation এর',
                'ইউরোপের':'europe এর','কোম্পানিতে':'comapny তে','এচিভ':'achieve','ডিটার্মিনেশন':'determination',
                'প্রেসিডেন্ট':'president','ওভারেই':'over এই', 'ডিস্ট্রাকশন':'distraction',
                'ওভারে':'over এ','টার্গেট':'target','মাষ্ট':'must',
                'লার্নিং':'learning','সোর্স':'source','মেইন':'main',
                'ফলো':'follow','ব্যাংকের':'bank এর','টিউটোরিয়াল':'tutorial',
                'ডলার':'dollar','লিংকডইন':'linkedin','ম্যাচের':'match এর',
                'ম্যাচে':'match এ','ভিডিওতে':'video তে','এক্স':'ex',
                'সল্ভ':'solve','অফিসের':'office এর','লাইকের':'like এর','ফেসবুকে':'facebook এ',
                'পোস্টের':'post এর','অপশনে':'option এ','ক্লিক':'click',
                'অপশন':'option','জার্মানিতে':'germany তে','সেমিস্টারে':'semester এ',
                'বিলিয়ন':'billion','মেটার':'meta-র','সামার':'summer',
                'থ্রেডস':'threads','ওয়েব':'web','স্টুডেন্ট':'student ','কোর':'core',
                'মাস্টার্স':'masters','কোর্স':'course','অ্যাপের':'app এর',
                'নিউজিল্যান্ডের':'newzeland এর','ডিসেম্বর':'december',
                'অ্যাপল':'apple','স্মার্টফোনে':'smartphone এ',
                'অ্যাপের':'app এর','টিচার':'teacher ','অ্যাডমিশন':'admission',
                'মিনিমাম':'minimum','পোর্টফোলিও':'portfolio','বিল্ড':'build','প্রফেশনাল':'professional ',
                'লেভেলে':'level এ','নেটওয়ার্কিং':'networking','রোবট':'robot','রেজাল্ট':'result','রেজিস্ট্রেশন':'registration',
                'লিংকে':'link এ','জয়েন':'join','মার্কেটে':'market এ','অস্ট্রেলিয়া':'australia','আয়ারল্যান্ড':'Ireland',
                '৭সাতচল্লিশ':'সাতচল্লিশ','তিন০০':'তিনশত','levelে':'level এ','সিরিয়াস':'serious','নেটওয়ার্কিং':'networking',
                'শেয়ার':'share','ক্লাস':'class','জয়েন':'join','লাইফে':'life এ','৫-দশ':'পাঁচ থেকে দশ','জুয়েলার্স':'jewellers',
                'আদালত-১-এর':'আদালত-এক-এর','ফ্রেইম':'frame','ওয়েবসাইটে':'website এ','ওয়েবসাইটের':'website এর','ইনিংসের':'innings এর',
                'ব্যাটিংয়েও':'batting এও','exএআইয়ের':'ex AI এর','করপোরেশনের':'corporation এর','মেডিকেল':'medical','কলেজের':'college এর',
                'ফাইল':'file','কোচের':'coach এর','বিলিয়ন':'billion','বিভ্run্তি':'বিভ্রান্তি','১১১টি':'একশত এগার টি',
                '৩৫টি':'পঁয়ত্রিশ টি','core্স':'course','ফেব্রুয়ারি':'february','ব্যাটিংয়ের':'batting এর','কম্পিউটার':'computer','অপারেটর':'operator',
                'অনলাইন':'online','ডিজিটাল':'digital','ভিডিও':'video','জব':'job','ইন্টার্ন':'intern','চ্যালেঞ্জ':'challenge','ফোরামের':'forum এর',
                'ফোন':'phone','ব্যাকএন্ড':'backend','ফোকাস':'focus','প্রবলেম':'problem','মিনিংফুল':'meaningful','রিজনেবল':'reasonable','স্টিকারও':'steaker',
                'চ্যাটবট':'chatbot ','১৫-বিশ':'পনেরো থেকে বিশ',' ইংলিশ':'english','স্পিনার':'speaner','টেকনিকটাই':'technique টাই','এপ্লাই':'apply',
                'প্রোগ্রামিং':'programming','ওয়েব':'web','core্সে':'course এ','ইম্পরট্যান্ট':'important','টাস্ক':'task','রিক্যাপ':'recap','রিভিশন':'revision',
                'রিলাক্স':'relax','মডিউল':'module','মাইনিং':'mining','ডিপার্টমেন্টের':'department এর','ইন্টারনেট':'internet','লাইফের':'life এর','কন্ট্রোল':'control',
                'ওয়ার্ডফেন্সের':'Wordfence এর','ডাটাবেজ':'database','ডাটা':'data','টেস্ট':'test','সাবজেক্টগুলাতে':'subject গুলাতে','সাইবার':'cyber','আর্জেন্টাইন':'argentine',
                'সাইট':'site','অ্যামাজনের':'amazon এর','অ্যামাজন':'amazon','সার্ভিসের':'service এর','৩পাঁচটি':'পাঁচটি','অক্টোবর':'october','চ্যাটজিপিটি':'ChatGpt',
                'ব্রাস্ট':'brust','নাইন–eleven':'nine-eleven','মিড অন':'mid on','ড্রেসিংরুমে':'dreasing room এ','ফ্লোরে':'floor এ','পেপটাইডস':'peptides',
                'বাউন্সের':'bounce এর','স্লিপে':'slip এ','স্ক্রিনশট':'screen shot','পোস্ট':'post','ওয়াশিংটন':'washington','রুপি':'rupe','চেক-ইন':'check-in',
                'ব্যাগেজও':'baggage ও','এআই':'AI','প্যান্টের':'pant এর','হার্ডওয়ার্ক':'hardwork','ইনস্ট্যান্ট':'instant','লংটার্ম':'long-term',
                'ফিউচার':'future','সাবজেক্টে':'subject এ','এডমিশন':'admission','ডাক মোড':'dark mood','টুইটারে':'twitter এ',
                'levelের':'level এর','সিগ্নিফিক্যান্ট':'significant','গ্রোথ':'growth','জাম্প':'jump','স্টার্ট':'start','লাইনআপ':'line up',
                'বোলিংয়ে':'bowling এ','উইকেটও':'wicket ও','বুয়েট':'Buet','কংগ্রেস':'congress','ফুjobল':'ফুটবল','লং টেনিস':'long tennis',

                'টেবিল টেনিসে':'tabble tennis এ','ক্যাপ্টেন':'captain','নিউজ':'news','কোম্পানির':'company এর','এনরোল':'enroll','সিএসইর':'cse এর','১৯৬০':'উনিশ শত ষাট',
                'লেগ সাইডে':'leg side এ','ডটকম':'dot com','ডোmain':'domain','ফুল ফান্ড':'full fund','ইউনিversity':'university','জাস্ট':'just','কোম্পানি':'company',
                'স্ট্যান্ট':'stunt','threadsের':'threads এর','phoneে':'phone এ','অফার':'offer','গ্যারান্টি':'guarantee','অনার্স':'honours','২০২২':'দুই হাজার বাইশ','চেয়ারম্যান':'chairman',

                'টুল':'tool','ফ্রিজ':'fridge','newsিল্যান্ডে':'new zealand এ','বাস্কেটে':'busket এ','হিরোতে':'hero তে','পিকনিক':'picnic','পিকনিকের':'picnic এর','বাসেই':'bus এই','মেম্বার':'member',
                '৯০%':'নব্বই পারসেন্ট','১০%':'দশ পারসেন্ট','ভেন্যু':'venue ','১১০.৮০':'একশ দশ দশমিক আশি','সিরিয়াস':'serious','সিমিলার':'simmilar','মাইন্ডেড':'minded','ফ্রেন্ড':'friend ',
                'স্ট্যান্ট':'stunt','threadsের':'threads এর','phoneে':'phone এ','অফার':'offer','গ্যারান্টি':'guarantee','অনার্স':'honours','২০২২':'দুই হাজার বাইশ','চেয়ারম্যান':'chairman',
                'কো-অপারেটিভ':'co-operative ','হেল্প':'help','ফ্লোর':'floor','সাইকেলের':'cycle এর','ফিফটি':'fifty','ওপেনার':'opener','teamের':'team এর','বোনাস':'bonus',

                'আন্ডারগ্রেডের':'under-grade এর','আন্ডারগ্র্যাডের':'under-grade এর','classে':'class এ','congressের':'congress এর','আলফা':'alpha','হেলিক্যাল':'helical','পেপটাইড':'peptide','টাইলস':'tiles',
                'গ্রাইন্ডিং':'grinding','১৫ও':'পনের','বার্ড':'bard ','সাইডে':'side এ','মিডল':'middle','অর্ডারে':'order এ','ওপেনিং':'openning','স্core':'score','বেস্ট':'best',
                'ফেসবুক':'facebook','ইনস্টাগ্রামে':'instagram এ','অ্যান্টি–ভাইরাস':'anti-virus','আইphone':'Iphone','timeলেপস':'timelapes','পার্লামেন্ট':'parliament','octoberের':'ovtober এর',
                'আমাজনে':'amazon এ','ইন্ডিয়ানা':'indiana','জোন':'zone ','ট্রাপ':'trap','ট্রায়াল':'trial','ডাবিং':'dubbing ','অ্যাকাউন্টের':'account এর','ব্যাটিং':'batting','টসে':'toss এ',

                'ব্যাংক':'bank','গ্র্যান্ড':'grand','সিএনএন':'CNN ','স্যুটকেস':'suitcase ','সিরিজ':'series ','jobাবে':'জবাবে','লাইন':'line','টুইটে':'twit এ','ডার্ক':'dark','মোড':'mood',
                'হায়ারিং':'hiring','ম্যানেজার':'manager','উইকেট':'wicket','ব্যাট':'bat ','computerের':'computer এর','ডাক':'dark','মোর্ড':'mood','jobের':'job এর','১৫%':'পনের পারসেন্ট',
                'ক্লাব':'club','১৩':'তের','১২':'বার',

                'গেমের':'game এর','হায়ার':'hire','মেডিসিন':'medicine','জার্নালে':'journal এ','ফেবারিট':'favourite ','অবসিডিয়ান':'obsidian','প্রাইমারী':'primary','ওয়ানডে':'one day',
                'appleের':'apple এর','আইওএস':'IOS','আইপ্যাডওএস':'ipad os','ম্যাকওএস':'mac os','ওয়াচওএসের':'watch os এর','হ্যাকার':'hacker ','কোড':'code','ক্যাম্পাসের':'campus এর',
                'আইকনিক':'iconic','বাথরুম':'bathroom','%':'পারসেন্ট','অ্যাটর্নি':'attorney','জেনারেলের':'general এর','৪৫টি':'পঁয়তাল্লিশ টি','অফিস':'office','সাইকেল':'cycle ',
                'টি–টোয়েন্টি':'T-twenty','কোচিং':'coaching','ক্যারিয়ার':'career','টিউশন ফি':'tution fee','রিনিউয়েবল':'Renewable','এনার্জি':'energy','রিলেটেড':'related','সাবজেক্ট':'subject',
                'ডিমান্ড':'demand','ক্যাচ':'catch','আউটে':'out এ','২৫০':'দুইশত পঞ্চাশ','প্রোগ্রামার':'programmer','আইপ্যাড':'ipad','ওয়াচ':'watch','ম্যাক':'mac','ফিশিংয়ের':'fishing এর','cyberসিকিউরিটি':'cyber security',
                'অ্যান্ড':'and','ইনফ্রাস্ট্রাকচার':'infrastructure','সিকিউরিটি':'security','এজেন্সি':'agency',

                'কমেডি শো':'comedy show','এক্টিং':'acting','গেম':'game','ওয়েবsite':'website','রেজুমি':'resume','আপডেট':'update','এফোর্ট':'effort','কম্প্রোমাইজ':'compromise','ওলtopালট':'ওলটপালট',
                'justিন':'justin','ইউজ':'use',

                'সামিটের':'summit এর','প্রায়রিটি':'priority','সলিড':'solid','আর্জেন্ট':'argent','ইফেক্টিভ':'effective','ইউনিলিভার':'Unilever','officeে':'office এ','ব্যক্তিদের কল করে':'ব্যক্তিদের call করে',
                'threadsে':'threads এ','সার্ভারের':'server এর','কলগুলো':'call গুলো','আপলোডের':'upload এর','ইঞ্চি':'inch','প্রটোকল':'protocol','job্বার':'জব্বার','ইনফরমেশন':'information',
                'স্যাক্রিফাইস':'sacrifice','ডিসট্রাক্ট':'distract','ওয়েষ্ট':'waste','ইউটিলাইজ':'utilize',

                '৯ম':'নবম','গ্রেড':'grade','ওয়েবsiteে':'website এ','dark্তার':'ডাক্তার',' ের ':'এর ','testের':'test এর',' ে':'এ ','স্মার্ট':'smart','বায়িং হাউজে':'buying house এ',
                'প্রগ্রেস চেক':'progress check','এডাপ্ট':'adapt','ফেইসবুক':'facebook','প্লাটফর্ম':'platform','ডিজাইন':'design','এনগেইজড':'engaged','কনটেন্ট':'content','মেটা':'meta',
                'ডটনেট':'Dotnet','ওয়েবsiteে':'website এ',

                'নার্স':'nurse','এইচএসসি':'hsc','১০':'দশ','ইউনিএসিস্ট':'uni assist','প্রোfile':'profile','সার্ভ':'serve',

                'ওয়েবsiteে':'website এ','buildিংটার':'building টার','ল্যাংগুয়েজ':'language','ট্রান্সলেশন':'translation','লটারি':'lottery','কীবোর্ড':'keyboard','রিsourceের':'resource এর',

                '৬একটি':'একটি','টুইটার':'twitter', 'এপ্রিল থেকে একত্রিশ মে পর্যন্ত':'april থেকে একত্রিশ may পর্যন্ত','উইন্টার':'winter','২টা':'দুই টা','স্পেস-timeের':'space time এর','bankারদের':'banker দের',
                'নন-নিউরোনাল':'non-neuronal','linkedinের':'linkedin এর',

                'এসএসসি':'ssc','ইনকরপোরেশন':'incorporation','বিবিসি':'bbc','stadium এর পিচ':'stadium এর pitch','নেদারল্যান্ডস':'netherlands ','টেক্সটাইল':'textile','নোটিফিকেশনের':'notification এর',
                'লিংক':'link','ই–মেইল':'E-mail','লুtopাট':'লুটপাট','tution  ওয়েবার':'tution weber','রেকর্ড':'record','ইকোনমি':'economy','ট্রাভেল':'travel','ফ্lineেটওয়ার্ক':'fly network','অ্যাডোবি':'adobe ',
                'ইমেজ':'image','৯০':'নব্বই','সিএসই':'cse','হেডের':'head এর','বাংলাদেশ জুয়েলার্স সমিতি':'বাংলাদেশ jewellers সমিতি',

                'বোলার':'bowler','ডিপেন্ড':'depend','লাইফ':'life','ফ্যামিলি':'family','skillের':'skill এর','মাইক্রোphone':'micro phone','মিডিয়া':'media','অ্যাপেও':'app এও',
                'হল-mark group':'hall-mark group','সফটওয়্যার':'software','টেকনোলজি':'technology','নিউক্লিয়ার পাওয়ার':'nuclear power','জুলাই':'july','গ্যারাজে':'garage এ','macিনাক island':'Mackinac Island',
                'টি-টোয়েন্টি series  ড্র':'t-twenty series draw','সনি exপেরিয়া exজেড':'sony exporia xz','২৫':'পঁচিশ','পেটেন্ট':'Patent','ল্যাবরেটরিজ':'laboratories','bankে':'bank এ',

                'গুগল':'google','youtubeে':'youtube এ','হার্ডডিস্ক':'hard disk','ব্রাউজারের':'browser এর','বুকমার্কে':'bookmark এ','টিউটোরিয়াল':'tutorial','সিরিয়াসলি':'seriously','ফিনিশ':'finish','গুগলের':'google এর',
                'মিটিং':'meeting','রুমে':'room এ','১৬':'ষোল','ওপেন':'open','courseের':'course এর','রেভল্যুশনারি':'revolutionary','গার্ড':'guard','ফোর্স':'force','ফেব্রুয়ারি':'february',
                'picnicে':'picnic এ','picnicের':'picnic এর','courseে':'course এ','সেকেন্ড':'second','মিনিটে':'minute এ','লাস্টের':'last এর','পার্টnurseের':'partners',
                'এমপিএস':'mps','ইন্টারভিউ':'interview',

                'ইনস্টাগ্রাম':'instagram','প্রিপারেশন':'preparation','স্পনসর':'sponsor','ডকুমেন্টেশন':'documentation','রিসোর্চ':'resource','গাইডline':'guideline','গ্যালাক্টিক':'galactic',
                'অ্যালুমিনিয়াম':'aluminium','সার্টিফিকেট':'certificate','jobাবদিহির':'জবাবদিহির','serveারে':'server এ','ফটোশপে':'photoshop এ','জেনারেটিভ':'generative','রুলে':'rule এ',
                'চেয়ারম্যানের':'chairman এর','বিলিয়ন':'billion','bat ারির':'battery-র',

                'পিসিবি':'pcb','phoneালাপে':'ফোনালাপে','ওয়েবsiteের':'website এর','moodে':'mood এ','stup':'set up','ওয়ার্ডপ্রেসে':'word press এ','ওয়েবsiteের':'website এর','ইন্টারফেসের':'interface এর',
                'শুটিংয়ে':'shooting এ','সাউথ':'south','এশিয়ান':'asian','রেস্টুরেন্টে':'restaurant এ','ওয়েটার':'Waiter','সিম':'sim','সিমের':'sim এর','ভাইস':'vice','রেক্টর':'rector','সর্বোচ্চ দুই হাজার ৯ষোল':'সর্বোচ্চ দুই হাজার নয়শত ষোল',
                'ইংল্যান্ডের':'england এর','gameে':'game এ','ডেইলি':'daily','রুটিন':'routine','হ্যাবিট':'habit','কনভার্ট':'convert','পিপিপি':'ppp','৫৪টি':'চুয়ান্ন টি','sourceের':'source এর','topিক':'topic','সার্চের':'search এর',
                'টিউটোরিয়ালে':'tutorial এ','থিম':'theme','styleে':'style এ','টিউটোরিয়ালে':'tutorial এ','৯৫পারসেন্ট':'পঁচানব্বই পারসেন্ট',

                'স্যার':'sir','পার্কিং':'parking','কর্নফার্ম':'confirm','কিবোর্ড':'keyboard','ক্রিকেট বোর্ড':'cricket board','ডিগ্রি':'degree','চাকরি নট':'চাকরি not','ভিসা স্পন্সর':'visa sponsor',
                'দুই হাজার দুই৮এক জন':'দুই হাজার দুইশত একাশি জন','useিসির':'ugc-র','কিউআর':'QR','হোয়াটসঅ্যাপ':'whatsapp','computerে':'computer এ','বক্সে':'box এ','অ্যাকাউন্ট':'account ',
                'মেনুতে':'menu তে','ট্যাপ':'tap','হোয়াটসঅ্যাপ':'whatsapp',

                'কুইজ':'quiz','ট্যাবলেট':'tablet','comের':'com এর','wicketের':'wicket এর','mac্সওয়েলকে':'ম্যাক্সওয়েলকে','বুয়েটকে':'Buet কে','ওয়েবsiteে':'website এ','রাjobংশের':'রাজবংশের','লেটার':'letter',
                 '১৪টি':'চৌদ্দ টি','অস্ট্রেলিয়া':'australia','১৮টি':'আঠার টি','অস্ট্রেলিয়ার':'australia-র','ওয়ালে শেয়ার':'wall এ share','সেন্ড করতে হবে':'send করতে হবে','সমsir':'সমস্যার','ক্রপ':'crop',
                'ভাইরাস':'virus','কনসাল':'consult','সফটওয়্যারের':'software এর','ফোনের':'phone এর',

                'আর্toss':'আর্টসের','decemberের':'december এর','preparationের':'preparation এর','মেগা':'mega','wicketে':'wicket এ','officeারদের':'officer দের',
                'ল্যাংগুয়েজ':'language','এপেটাইজার':'appetizer','lineে':'line এ','অডিও-video':'audio-video','অ্যাপটিতে':'app টিতে','সুপ্রিম core্ট':'supreme court','পুলিশের':'police এর',

              'আইআরজিসি-কিউএফ':'IRGC-QF','ওয়াশিংটন':'washington','ই-মেইলের':'e-mail এর','বাংলাlink':'banglalink','হায়ার':'hire','ফর্মটা':'form টা','স্ট্যান্ডার্ড চাটার্ড bank':'Standard Chartered Bank',
                'newsিল্যান্ড':'New Zealand','ইনিংসেও':'inniongs এও','ল্যাবের':'lab এর','৫টি':'পাঁচ টি','অলরাউন্ডারের':'all rounder এর','টেক্সাসে':'texas এ',

                '(বুয়েট)':'Buet','metaনোর':'মেটানোর','webার ডয়চে':'ওয়েবার ডয়চে','novemberে':'november এ','ফ্লাইটের':'flight এর','ফ্লাইটটি':'flight টি','ওয়াশিংটনের':'washington এর',

                'serveিসেসের':'service এর','macডোনাল্ডসের':'McDonalds এর','ওয়াশিংটন':'washington','রিsource':'resource','সিরিয়াসলি':'seriously','developমেন্ট':'development','ওয়ার্ডফেন্সের':'Wordfence এর',
                'ওয়ার্ডফেন্স':'Wordfence','marchের':'march এর','galacticে':'galactic এ','ওয়েবsiteে যুক্ত':'website এ যুক্ত','প্রিমিয়ামে':'premium এ','jumpার':'জাম্পার',











                }

def rep_bn_en(text):
  for key, value in replace_dict.items():
    text = text.replace(key, value)
  return text

train_csv.Text = train_csv.Text.map(rep_bn_en)

# %%
def num_to_word(text):
  list_num = bn.find_numbers(text, alphanumeric=False)
  for i in list_num:
    text = text.replace(i,bn.number_to_word(i))
  return text

train_csv.Text = train_csv.Text.map(num_to_word)

# %%
with pd.option_context('display.max_colwidth', 0):
    display(train_csv['Text'][1:50])
# Out:
# 1     তিনি আল-জাজিরাকে বলেন, ‘নয় হাজার পাঁচ শত কোটি dollar এর budget, এর মানে হলো যুক্তরাষ্ট্রের কেন্দ্রীয় budget এর পরিমাণ উল্লেখজনক পরিমাণে বেড়েছে।
# 2     অবশ্য এখন সংখ্যাটি আরও বেড়েছে। অধিভুক্ত college ও মাদ্রাসার শিক্ষার্থীসহ দেশের সরকারি–বেসরকারি মিলিয়ে বিশ্ববিদ্যালয়গুলোতে total শিক্ষার্থী সাতচল্লিশ লাখ ছাপ্পান্ন হাজার ৭সাতচল্লিশ জন।
# 3     কেন্দ্রীয় স্বরাষ্ট্র প্রতিমন্ত্রী নিত্যানন্দ রাই। বৈঠকে ফসলের minimum সহায়ক মূল্য বা MSP-র সঙ্গে কেন্দ্রীয় সরকার শস্য বৈচিত্র্যকে জুড়ে দেওয়ার proposal দেন।
# 4     এ ক্ষেত্রে তাঁরা হামাসের অতীতের বক্তৃতা–বয়ানের উদ্ধৃতি দিচ্ছেন। America এর  প্রতিনিধি পরিষদের আইনপ্রণেতারা স্লোগানটিকে ‘ইহুদিবিদ্বেষী’ অভিহিত করে আইন প্রণয়ন করেছেন।
# 5     অনেকেই দেখলাম GRE RC Section নিয়ে চিন্তিত, মনে রাখবেন, regular practise ব্যতীত RC section এ improve করা একপ্রকার impossible ব্যাপার।
# 6     এমন যুক্তি দিয়ে তিনি press conference এ বলেন, ‘ত্রিশ বছর ধরে আমি একই অবস্থান ধরে রেখেছি। আমি খুব easy  কথাই বলছি।’
# 7     some will understand and work on their weaknesses. We hope Litton Das will take it on a positive note and come back stronger than ever in the ODI side.
# 8     পাঞ্জাব, হরিয়ানা ও উত্তর প্রদেশের পশ্চিমাঞ্চলের ধান, গম ও আখ চাষের কারণে কৃষিজমির জলস্তর rapidly কমে যাচ্ছে।
# 9     congressional কমিটির নেতাদের অনুমোদন পেতে হবে। সে ক্ষেত্রে details  এই proposal এ change  আনা হতে পারে।
# 10    বাকি সব engineer দের কাজে technology এর ব্যবহার বাড়লেও civil engineer , mechanical , chemical, marine engineer এসব subject এর demand এখনকার দিনের মতো রয়ে যাবে।
# 11    সে অনেক try করলো। email, phone, job site , apply, meeting set, অনেক কিছু করলো। কিন্তু কাজ হলো না।
# 12    opportunity grap করে না। তাদের চাকরি খেয়ে দেয়। আর যারা adapt  করে, তারা আগের চাইতে দুই-তিনগুণ ভালো করবে। যেমন ChatGPT এর কারণে job কিন্তু কমে নাই। বরং ChatGPT দিয়ে সফটওয়্যার বানানোর job বাড়ছে
# 13    প্রায় তিন হাজার তিন০০ বিভিন্ন রকম কোষ রয়েছে মানুষের মস্তিষ্কে। এত দিন এ বিষয়ে বিস্তারিত তথ্য জানা না থাকলেও এবার মানুষের মস্তিষ্কের largest বা পূর্ণাঙ্গ map প্রকাশ করেছেন গবেষকেরা।
# 14    third party tools এর সাথে software integration। একটা software অনেক developer  মিলে বানায়। তাই অন্যের code  দেখে বুঝার ability ।
# 15    করলে আমি next semester ধরতে পারব না, তুমি একটু কষ্ট করে, teacher দের কাছ থেকে feedback নাও। শেষমেষ,  সতেরো november ২০দশ তারিখে cse department থেকে স্বপ্নের admission পেয়ে গেলাম।
# 16    Penselvania state এ  এক সমাবেশে ট্রাম্পের করা মন্তব্য নিয়ে এর আগে জো বাইডেনের administration ও প্রতিক্রিয়া জানিয়েছে।
# 17    কেমন হতো যদি এমন এক পৃথিবীতে বাস করা যেত, যেখানে শহরের কোলাহল বা jam নেই, কাজের ঝামেলা নেই, বনের ভেতরে থাকা ছোট একটি ঘরে কাটিয়ে দেওয়া যেত whole life।
# 18    শিক্ষামন্ত্রী বলেন, দেশের শিক্ষাপ্রতিষ্ঠানে যে education system চালু হচ্ছে, ওই শিক্ষাব্যবস্থায় মেধাবী একটি জাতি তৈরি হবে।
# 19    minimum ছয় মাস থেকে একবছর super সিরিয়াস থেকে skill এর প্রাথমিক level develop করে। একটা portfolio build করো। সেটা অন্য professional দের সাথে শেয়ার করা। একটা level এ পৌঁছানোর পর নেটওয়ার্কিং করো।
# 20    Emon rarely gets opportunities to play games in any platform and in most cases, he didn’t deserve to sit on the bench
# 21    অর্থাৎ professional life এ প্রবেশ করলে versity তে যা যা শিখে আসছো তার চাইতে বেশি জিনিস শিখতে হবে। communication skill, technology use করে কিছু করার ability গড়ে তুলতে হবে।
# 22    pump নষ্টও করে ফেলছিলাম। পরে নতুন pump কিনে সেটা ঠিক করা লাগছে। বাসা বাড়ির কাজ আমি না পারলেও youtube দেখে দেখে পাকনামি করতে যাই।
# 23    আর macস্লিপি অস্ত্রোপচারের কাজটা সুচারু করার জন্য ছিল ভিঞ্চির যোগ্য  assistant। robot দিয়ে মানুষের অস্ত্রোপচারে এই সফলতার পর দ্য ভিঞ্চি ও macস্লিপিকে জুটি করে আরও কিছু অস্ত্রোপচার complete করা হয়।
# 24    28 February result প্রকাশ করা হবে এবং এক march থেকে class শুরু হবে।registration করুন এই link এ GRE & IELTS Prep BD” group -এ জয়েন করুন,
# 25    অনেকে stock market এ বিনিয়োগ করছেন। ফলে চলতি বছর জাপানের stock market এর পর সবচেয়ে বেশি সূচক বেড়েছে তুরস্কের stock market এর।
# 26    England  ও South Africa থেকে australia, Ireland ও যুক্তরাষ্ট্রেও এ প্রকল্প চালানো হয়েছে। পাঁচ শতাধিক প্রতিষ্ঠান এ প্রকল্পে participate করেছে।
# 27    অনেকেই মনে করেন, পানিতে পড়ে গেলে দ্রুত চালের মধ্যে রেখে phone set টি  বাঁচানো যাবে। internet এ এমন তথ্য ভূরি ভূরি।আসল সত্যিটা জানা যাক। চাল জলীয় পদার্থ absorb করে, এটা ঠিক।
# 28    নদী থেকে সমুদ্র পর্যন্ত’ শব্দবন্ধ ইসরায়েল ও যুক্তরাষ্ট্র দুই দেশেই debate এর জন্ম দিয়েছে। এই শব্দবন্ধ ব্যবহার করে দেশ দুটিতে ফিলিস্তিনিপন্থী বিক্ষোভকারীরা
# 29    বিশেষ করে Positive Test, Negative Test, Boundary Test, Corner Case, এইগুলা সম্পর্কে ধারণা নিবে। code coverage বের করতে পারলে খুবই ভালো।
# 30    The tail-ender is not exposed yet. Such commentary in international level is embarrassing to the next level.
# 31    মনে রাইখো-- deadline ইজ deadline। আর দুই হাজার চব্বিশ ইজ দুই হাজার চব্বিশ। life এ দুই হাজার চব্বিশ  একবারই আসবে। tutorial দেখে করতে পারি। কিন্তু নিজে নিজে project বা কোন আলাদা কাজ করতে দিলে সেটা পারিনা।
# 32    এর আগে জাতিসংঘের নিরাপত্তা পরিষদে আলজেরিয়া অবিলম্বে যুদ্ধবিরতির প্রস্তাব এনেছিল আলজেরিয়া। কিন্তু অবিলম্বে শব্দটির জন্য আপত্তি জানায় যুক্তরাষ্ট্র
# 33    career গঠনের পাশাপাশি দেশের economics এ আবদান রাখেন তাঁরা। এ বিষয়ে higher studies এর জন্য প্রতিবছর বাংলাদেশ থেকে উল্লেখযোগ্যসংখ্যক শিক্ষার্থী বিদেশে পাড়ি দেন।
# 34    তাই আমি যেসব আরব family এর সঙ্গে বেড়ে উঠেছি, তাদের কখনোই এসব খবরে কান দিতে দেখিনি। দুই হাজার সালে বাবা পরিবার নিয়ে এ city তে চলে আসেন।
# 35    Devin কিন্তু productivity tools এর পথে হাটতেছে না। বরং সে যে পথে হাটতেছে next  ৫-দশ বছরে ডেভিন, কেভিন, নবিন বা "মমিন AI" নামের কেউ complex project করে দেয়া শুরু করলে অবাক হওয়ার কিছুই থাকবে না।
# 36    polio টিকাদান কর্মীদের security তে তাঁরা involved ছিলেন। দেশটির employees এই তথ্য জানিয়েছেন।
# 37    Tree related algorithm, এবং Time complexity কিভাবে বের করতে হয়। object oriented programming এর principal apply করতে জানতে হবে।
# 38    microsoft এর তথ্যমতে, কৃত্রিম বুদ্ধিমত্তা tool টি email লিখে দেওয়া ছাড়াও অন্যদের পাঠানো email গুরুত্বপূর্ণ তথ্য সংক্ষেপে জানাতে পারে। ফলে অন্যদের পাঠানো আকারে বড় email না খুলেই সেখানে থাকা গুরুত্বপূর্ণ তথ্য জানতে পারবেন ব্যবহারকারীরা।
# 39    দলের আবহটা এখন বেশ ভালো। আমরা পরের matchএর জন্য মুখিয়ে আছি।’ hopefully পরের match ও জিততে পারব।
# 40    technical podcast শুনতে পারো। সময় থাকলে open source project এ contribute করতে পারো।
# 41    তবে আমি জিনিসগুলো শিখব। দরকার হলে আপনি test নিবেন। আর তার বদলে আমি masters এর দুইটা course নিবো।
# 42    তাই বাধ্য হয়ে পায়ে হেঁটেই যাওয়া আসা করতাম। আর প্রতিদিন বাসায় ফিরে bank এর website এ ঢুকে দেখতাম। কত টাকা ঢুকেছে।
# 43    AI bug bounty কর্মসূচিতে অংশ নিয়ে একাধিক ত্রুটিও শনাক্ত করা যাবে। ত্রুটি শনাক্তের পর microsoft security research centre portal এ প্রতিবেদন জমা দিতে হবে। এরপর ত্রুটিগুলো পর্যালোচনা করে সন্ধানদাতাদের পুরস্কার দেবে microsoft।
# 44    পশ্চিমা সামরিক জোট nato যেসব সদস্যদেশ জোটে তাদের বকেয়া paid করে না, সেসব দেশে হামলা চালাতে রাশিয়াকে motivate করবেন,
# 45    Customers আগ্রহ দেখাচ্ছেন নরম কাপড় আর কম কাজের প্রতি। এই weather এ এটাই উপযোগী। ঢিলেঢালা লম্বা বা ছোট কুর্তা, top বা shirt চলতি ধারায়ও চলছে। busy দিনে style আর স্বস্তি দুটোই পাওয়া যায়।
# 46    অন্যদিকে AI বাবাজির তো ছুটি লাগবে না। প্রতিদিন চব্বিশ ঘন্টা করে সপ্তাহে সাত কাজ করবে। আর ডেভিন team member  হিসেবে জায়গা পেলে, কারো না কারো জায়গাতো সে খাবেই।
# 47    এছাড়াও পাহাড়ে hiking, কাঁদায় team member এর পড়ে যায়, চা বাগান, লেকে যাওয়া ছাড়াও resort এ ছিল sports activity। প্রতিদিন ভোরে দৌড়। badminton এ partner এর জোরে সম্মানজনক কৌটায় জিতেছি।
# 48    দীর্ঘদিন থেকে মহাকাশ পর্যটন launch করার জন্য কাজ করছে মার্কিন organization virgin galactic। এবার August month এ  প্রথমবারের মতো পর্যটক নিয়ে মহাকাশ ভ্রমণে যাওয়ার ঘোষণা দিয়েছেন virgin galactic এর প্রতিষ্ঠাতা রিচার্ড ব্রনসন।
# 49    Although Rishad is no where near Hasaranga’s class, but playing Taijul over him in this flat track again might turn into a big mistake
# Name: Text, dtype: object

# %% [markdown]
# **Validation**

# %%
val_xlxs = pd.concat([X_val, y_val], axis=1)
val_xlxs.head()
# Out:
#                       id                                               Text
# 526  Recording (527).wav  পরে এসব ভুয়া ছবি, video বা কৃত্রিম কণ্ঠস্বর কা...
# 354  Recording (355).wav  পাকিস্তানের বিপক্ষে টানা চারটি century ওয়ার্না...
# 168  Recording (169).wav  ফজলে এলাহীর বাড়ি কুড়িগ্রামের উলিপুর upazila । ...
# 135  Recording (136).wav  তারা protein এর সেই ‘ক্ষুদ্র কিন্তু important ...
# 937  Recording (938).wav  বিষয়টা খুলে বলব। তারপর উনার office এ যাওয়ার পর...

# %%
#convert val_xlxs to val_csv

val_xlxs.to_csv('val_csv', index=False)

# %%
#Load val_csv format
val_csv = pd.read_csv('val_csv')
val_csv.head()
# Out:
#                     id                                               Text
# 0  Recording (527).wav  পরে এসব ভুয়া ছবি, video বা কৃত্রিম কণ্ঠস্বর কা...
# 1  Recording (355).wav  পাকিস্তানের বিপক্ষে টানা চারটি century ওয়ার্না...
# 2  Recording (169).wav  ফজলে এলাহীর বাড়ি কুড়িগ্রামের উলিপুর upazila । ...
# 3  Recording (136).wav  তারা protein এর সেই ‘ক্ষুদ্র কিন্তু important ...
# 4  Recording (938).wav  বিষয়টা খুলে বলব। তারপর উনার office এ যাওয়ার পর...

# %%
len(val_csv)
# Out:
# 320

# %% [markdown]
# val:

# %%
replace_dict = {'ডলারের': 'dollar এর','মেম্বারের':'member এর',
                'এমএসপির': 'MSP-র','রেগুলার': 'regular','প্রাকটিস':'practise',
                'কমিটি ':'committee-','সফটওয়্যার':'software','রিসোর্টে':'resort এ',
                'নভেম্বর':'november','শার্ট':'shirt','স্পোর্টস':'sports',
                'সুপার':'super','সিরিয়াস':'serious','স্কিল':'skill','লেভেল':'level',
                'ডেভেলপ':'develop','শেয়ার':'share','ভার্সিটি':'versity ','শেয়ার':'share',
                'ইউটিউব':'youtube','স্টাইল':'style',
                'মার্চ':'march','গ্রুপ':'group','স্টক':'stock','হাইকিং':'hiking',
                'মার্কেটের':'market এর','ডেডলাইন':'deadline','এক্টিভিটি':'activity',
                'প্রজেক্ট':'project','ব্যাডমিন্টনে':'badminton এ',
                'ম্যাচ':'match ','মাস্টার্সের':'masters এর','টপ':'top','পার্টনারের':'partner এর',
                'টিম':'team','ভার্জিন':'virgin','রোমান':'roman','গ্যালাক্টিকের':'galactic এর',
                'টেলিস্কোপের':'telescope এর','ক্রেডিট':'credit','পিওর':'pure','গোল্ড':'gold',
                'কার্ডের':'card এর','কার্ড':'card','জুয়েলার্স':'jewellers','ডিস্ট্রাকশনের':'distraction এর',
                'প্লাস':'plus','স্পেসিফিক':'specific','টাইম':'time',
                'ইজি':'easy','ওয়েবসাইটে':'website এ','ক্যারিয়ার':'career','মিডউইকেটে':'midwicket',
                'ওয়েবসাইটের':'website এর','ট্রাম্পকে':'trump কে','আইডিয়া':'idea',
                'ফেব্রুয়ারি':'february','স্টুডেন্ট':'student','পোলিও':'polio','জেনারেশনের':'generation এর',
                'ইউরোপের':'europe এর','কোম্পানিতে':'comapny তে','এচিভ':'achieve','ডিটার্মিনেশন':'determination',
                'প্রেসিডেন্ট':'president','ওভারেই':'over এই', 'ডিস্ট্রাকশন':'distraction',
                'ওভারে':'over এ','টার্গেট':'target','মাষ্ট':'must',
                'লার্নিং':'learning','সোর্স':'source','মেইন':'main',
                'ফলো':'follow','ব্যাংকের':'bank এর','টিউটোরিয়াল':'tutorial',
                'ডলার':'dollar','লিংকডইন':'linkedin','ম্যাচের':'match এর',
                'ম্যাচে':'match এ','ভিডিওতে':'video তে','এক্স':'ex',
                'সল্ভ':'solve','অফিসের':'office এর','লাইকের':'like এর','ফেসবুকে':'facebook এ',
                'পোস্টের':'post এর','অপশনে':'option এ','ক্লিক':'click',
                'অপশন':'option','জার্মানিতে':'germany তে','সেমিস্টারে':'semester এ',
                'বিলিয়ন':'billion','মেটার':'meta-র','সামার':'summer',
                'থ্রেডস':'threads','ওয়েব':'web','স্টুডেন্ট':'student ','কোর':'core',
                'মাস্টার্স':'masters','কোর্স':'course','অ্যাপের':'app এর',
                'নিউজিল্যান্ডের':'newzeland এর','ডিসেম্বর':'december',
                'অ্যাপল':'apple','স্মার্টফোনে':'smartphone এ',
                'অ্যাপের':'app এর','টিচার':'teacher ','অ্যাডমিশন':'admission',
                'মিনিমাম':'minimum','পোর্টফোলিও':'portfolio','বিল্ড':'build','প্রফেশনাল':'professional ',
                'লেভেলে':'level এ','নেটওয়ার্কিং':'networking','রোবট':'robot','রেজাল্ট':'result','রেজিস্ট্রেশন':'registration',
                'লিংকে':'link এ','জয়েন':'join','মার্কেটে':'market এ','অস্ট্রেলিয়া':'australia','আয়ারল্যান্ড':'Ireland',
                '৭সাতচল্লিশ':'সাতচল্লিশ','তিন০০':'তিনশত','levelে':'level এ','সিরিয়াস':'serious','নেটওয়ার্কিং':'networking',
                'শেয়ার':'share','ক্লাস':'class','জয়েন':'join','লাইফে':'life এ','৫-দশ':'পাঁচ থেকে দশ','জুয়েলার্স':'jewellers',
                'আদালত-১-এর':'আদালত-এক-এর','ফ্রেইম':'frame','ওয়েবসাইটে':'website এ','ওয়েবসাইটের':'website এর','ইনিংসের':'innings এর',
                'ব্যাটিংয়েও':'batting এও','exএআইয়ের':'ex AI এর','করপোরেশনের':'corporation এর','মেডিকেল':'medical','কলেজের':'college এর',
                'ফাইল':'file','কোচের':'coach এর','বিলিয়ন':'billion','বিভ্run্তি':'বিভ্রান্তি','১১১টি':'একশত এগার টি',
                '৩৫টি':'পঁয়ত্রিশ টি','core্স':'course','ফেব্রুয়ারি':'february','ব্যাটিংয়ের':'batting এর','কম্পিউটার':'computer','অপারেটর':'operator',
                'অনলাইন':'online','ডিজিটাল':'digital','ভিডিও':'video','জব':'job','ইন্টার্ন':'intern','চ্যালেঞ্জ':'challenge','ফোরামের':'forum এর',
                'ফোন':'phone','ব্যাকএন্ড':'backend','ফোকাস':'focus','প্রবলেম':'problem','মিনিংফুল':'meaningful','রিজনেবল':'reasonable','স্টিকারও':'steaker',
                'চ্যাটবট':'chatbot ','১৫-বিশ':'পনেরো থেকে বিশ',' ইংলিশ':'english','স্পিনার':'speaner','টেকনিকটাই':'technique টাই','এপ্লাই':'apply',
                'প্রোগ্রামিং':'programming','ওয়েব':'web','core্সে':'course এ','ইম্পরট্যান্ট':'important','টাস্ক':'task','রিক্যাপ':'recap','রিভিশন':'revision',
                'রিলাক্স':'relax','মডিউল':'module','মাইনিং':'mining','ডিপার্টমেন্টের':'department এর','ইন্টারনেট':'internet','লাইফের':'life এর','কন্ট্রোল':'control',
                'ওয়ার্ডফেন্সের':'Wordfence এর','ডাটাবেজ':'database','ডাটা':'data','টেস্ট':'test','সাবজেক্টগুলাতে':'subject গুলাতে','সাইবার':'cyber','আর্জেন্টাইন':'argentine',
                'সাইট':'site','অ্যামাজনের':'amazon এর','অ্যামাজন':'amazon','সার্ভিসের':'service এর','৩পাঁচটি':'পাঁচটি','অক্টোবর':'october','চ্যাটজিপিটি':'ChatGpt',
                'ব্রাস্ট':'brust','নাইন–eleven':'nine-eleven','মিড অন':'mid on','ড্রেসিংরুমে':'dreasing room এ','ফ্লোরে':'floor এ','পেপটাইডস':'peptides',
                'বাউন্সের':'bounce এর','স্লিপে':'slip এ','স্ক্রিনশট':'screen shot','পোস্ট':'post','ওয়াশিংটন':'washington','রুপি':'rupe','চেক-ইন':'check-in',
                'ব্যাগেজও':'baggage ও','এআই':'AI','প্যান্টের':'pant এর','হার্ডওয়ার্ক':'hardwork','ইনস্ট্যান্ট':'instant','লংটার্ম':'long-term',
                'ফিউচার':'future','সাবজেক্টে':'subject এ','এডমিশন':'admission','ডাক মোড':'dark mood','টুইটারে':'twitter এ',
                'levelের':'level এর','সিগ্নিফিক্যান্ট':'significant','গ্রোথ':'growth','জাম্প':'jump','স্টার্ট':'start','লাইনআপ':'line up',
                'বোলিংয়ে':'bowling এ','উইকেটও':'wicket ও','বুয়েট':'Buet','কংগ্রেস':'congress','ফুjobল':'ফুটবল','লং টেনিস':'long tennis',

                'টেবিল টেনিসে':'tabble tennis এ','ক্যাপ্টেন':'captain','নিউজ':'news','কোম্পানির':'company এর','এনরোল':'enroll','সিএসইর':'cse এর','১৯৬০':'উনিশ শত ষাট',
                'লেগ সাইডে':'leg side এ','ডটকম':'dot com','ডোmain':'domain','ফুল ফান্ড':'full fund','ইউনিversity':'university','জাস্ট':'just','কোম্পানি':'company',
                'স্ট্যান্ট':'stunt','threadsের':'threads এর','phoneে':'phone এ','অফার':'offer','গ্যারান্টি':'guarantee','অনার্স':'honours','২০২২':'দুই হাজার বাইশ','চেয়ারম্যান':'chairman',

                'টুল':'tool','ফ্রিজ':'fridge','newsিল্যান্ডে':'new zealand এ','বাস্কেটে':'busket এ','হিরোতে':'hero তে','পিকনিক':'picnic','পিকনিকের':'picnic এর','বাসেই':'bus এই','মেম্বার':'member',
                '৯০%':'নব্বই পারসেন্ট','১০%':'দশ পারসেন্ট','ভেন্যু':'venue ','১১০.৮০':'একশ দশ দশমিক আশি','সিরিয়াস':'serious','সিমিলার':'simmilar','মাইন্ডেড':'minded','ফ্রেন্ড':'friend ',
                'স্ট্যান্ট':'stunt','threadsের':'threads এর','phoneে':'phone এ','অফার':'offer','গ্যারান্টি':'guarantee','অনার্স':'honours','২০২২':'দুই হাজার বাইশ','চেয়ারম্যান':'chairman',
                'কো-অপারেটিভ':'co-operative ','হেল্প':'help','ফ্লোর':'floor','সাইকেলের':'cycle এর','ফিফটি':'fifty','ওপেনার':'opener','teamের':'team এর','বোনাস':'bonus',

                'আন্ডারগ্রেডের':'under-grade এর','আন্ডারগ্র্যাডের':'under-grade এর','classে':'class এ','congressের':'congress এর','আলফা':'alpha','হেলিক্যাল':'helical','পেপটাইড':'peptide','টাইলস':'tiles',
                'গ্রাইন্ডিং':'grinding','১৫ও':'পনের','বার্ড':'bard ','সাইডে':'side এ','মিডল':'middle','অর্ডারে':'order এ','ওপেনিং':'openning','স্core':'score','বেস্ট':'best',
                'ফেসবুক':'facebook','ইনস্টাগ্রামে':'instagram এ','অ্যান্টি–ভাইরাস':'anti-virus','আইphone':'Iphone','timeলেপস':'timelapes','পার্লামেন্ট':'parliament','octoberের':'ovtober এর',
                'আমাজনে':'amazon এ','ইন্ডিয়ানা':'indiana','জোন':'zone ','ট্রাপ':'trap','ট্রায়াল':'trial','ডাবিং':'dubbing ','অ্যাকাউন্টের':'account এর','ব্যাটিং':'batting','টসে':'toss এ',

                'ব্যাংক':'bank','গ্র্যান্ড':'grand','সিএনএন':'CNN ','স্যুটকেস':'suitcase ','সিরিজ':'series ','jobাবে':'জবাবে','লাইন':'line','টুইটে':'twit এ','ডার্ক':'dark','মোড':'mood',
                'হায়ারিং':'hiring','ম্যানেজার':'manager','উইকেট':'wicket','ব্যাট':'bat ','computerের':'computer এর','ডাক':'dark','মোর্ড':'mood','jobের':'job এর','১৫%':'পনের পারসেন্ট',
                'ক্লাব':'club','১৩':'তের','১২':'বার',

                'গেমের':'game এর','হায়ার':'hire','মেডিসিন':'medicine','জার্নালে':'journal এ','ফেবারিট':'favourite ','অবসিডিয়ান':'obsidian','প্রাইমারী':'primary','ওয়ানডে':'one day',
                'appleের':'apple এর','আইওএস':'IOS','আইপ্যাডওএস':'ipad os','ম্যাকওএস':'mac os','ওয়াচওএসের':'watch os এর','হ্যাকার':'hacker ','কোড':'code','ক্যাম্পাসের':'campus এর',
                'আইকনিক':'iconic','বাথরুম':'bathroom','%':'পারসেন্ট','অ্যাটর্নি':'attorney','জেনারেলের':'general এর','৪৫টি':'পঁয়তাল্লিশ টি','অফিস':'office','সাইকেল':'cycle ',
                'টি–টোয়েন্টি':'T-twenty','কোচিং':'coaching','ক্যারিয়ার':'career','টিউশন ফি':'tution fee','রিনিউয়েবল':'Renewable','এনার্জি':'energy','রিলেটেড':'related','সাবজেক্ট':'subject',
                'ডিমান্ড':'demand','ক্যাচ':'catch','আউটে':'out এ','২৫০':'দুইশত পঞ্চাশ','প্রোগ্রামার':'programmer','আইপ্যাড':'ipad','ওয়াচ':'watch','ম্যাক':'mac','ফিশিংয়ের':'fishing এর','cyberসিকিউরিটি':'cyber security',
                'অ্যান্ড':'and','ইনফ্রাস্ট্রাকচার':'infrastructure','সিকিউরিটি':'security','এজেন্সি':'agency',

                'কমেডি শো':'comedy show','এক্টিং':'acting','গেম':'game','ওয়েবsite':'website','রেজুমি':'resume','আপডেট':'update','এফোর্ট':'effort','কম্প্রোমাইজ':'compromise','ওলtopালট':'ওলটপালট',
                'justিন':'justin','ইউজ':'use',

                'সামিটের':'summit এর','প্রায়রিটি':'priority','সলিড':'solid','আর্জেন্ট':'argent','ইফেক্টিভ':'effective','ইউনিলিভার':'Unilever','officeে':'office এ','ব্যক্তিদের কল করে':'ব্যক্তিদের call করে',
                'threadsে':'threads এ','সার্ভারের':'server এর','কলগুলো':'call গুলো','আপলোডের':'upload এর','ইঞ্চি':'inch','প্রটোকল':'protocol','job্বার':'জব্বার','ইনফরমেশন':'information',
                'স্যাক্রিফাইস':'sacrifice','ডিসট্রাক্ট':'distract','ওয়েষ্ট':'waste','ইউটিলাইজ':'utilize',

                '৯ম':'নবম','গ্রেড':'grade','ওয়েবsiteে':'website এ','dark্তার':'ডাক্তার',' ের ':'এর ','testের':'test এর',' ে':'এ ','স্মার্ট':'smart','বায়িং হাউজে':'buying house এ',
                'প্রগ্রেস চেক':'progress check','এডাপ্ট':'adapt','ফেইসবুক':'facebook','প্লাটফর্ম':'platform','ডিজাইন':'design','এনগেইজড':'engaged','কনটেন্ট':'content','মেটা':'meta',
                'ডটনেট':'Dotnet','ওয়েবsiteে':'website এ',

                'নার্স':'nurse','এইচএসসি':'hsc','১০':'দশ','ইউনিএসিস্ট':'uni assist','প্রোfile':'profile','সার্ভ':'serve',

                'ওয়েবsiteে':'website এ','buildিংটার':'building টার','ল্যাংগুয়েজ':'language','ট্রান্সলেশন':'translation','লটারি':'lottery','কীবোর্ড':'keyboard','রিsourceের':'resource এর',

                '৬একটি':'একটি','টুইটার':'twitter', 'এপ্রিল থেকে একত্রিশ মে পর্যন্ত':'april থেকে একত্রিশ may পর্যন্ত','উইন্টার':'winter','২টা':'দুই টা','স্পেস-timeের':'space time এর','bankারদের':'banker দের',
                'নন-নিউরোনাল':'non-neuronal','linkedinের':'linkedin এর',

                'এসএসসি':'ssc','ইনকরপোরেশন':'incorporation','বিবিসি':'bbc','stadium এর পিচ':'stadium এর pitch','নেদারল্যান্ডস':'netherlands ','টেক্সটাইল':'textile','নোটিফিকেশনের':'notification এর',
                'লিংক':'link','ই–মেইল':'E-mail','লুtopাট':'লুটপাট','tution  ওয়েবার':'tution weber','রেকর্ড':'record','ইকোনমি':'economy','ট্রাভেল':'travel','ফ্lineেটওয়ার্ক':'fly network','অ্যাডোবি':'adobe ',
                'ইমেজ':'image','৯০':'নব্বই','সিএসই':'cse','হেডের':'head এর','বাংলাদেশ জুয়েলার্স সমিতি':'বাংলাদেশ jewellers সমিতি',

                'বোলার':'bowler','ডিপেন্ড':'depend','লাইফ':'life','ফ্যামিলি':'family','skillের':'skill এর','মাইক্রোphone':'micro phone','মিডিয়া':'media','অ্যাপেও':'app এও',
                'হল-mark group':'hall-mark group','সফটওয়্যার':'software','টেকনোলজি':'technology','নিউক্লিয়ার পাওয়ার':'nuclear power','জুলাই':'july','গ্যারাজে':'garage এ','macিনাক island':'Mackinac Island',
                'টি-টোয়েন্টি series  ড্র':'t-twenty series draw','সনি exপেরিয়া exজেড':'sony exporia xz','২৫':'পঁচিশ','পেটেন্ট':'Patent','ল্যাবরেটরিজ':'laboratories','bankে':'bank এ',

                'গুগল':'google','youtubeে':'youtube এ','হার্ডডিস্ক':'hard disk','ব্রাউজারের':'browser এর','বুকমার্কে':'bookmark এ','টিউটোরিয়াল':'tutorial','সিরিয়াসলি':'seriously','ফিনিশ':'finish','গুগলের':'google এর',
                'মিটিং':'meeting','রুমে':'room এ','১৬':'ষোল','ওপেন':'open','courseের':'course এর','রেভল্যুশনারি':'revolutionary','গার্ড':'guard','ফোর্স':'force','ফেব্রুয়ারি':'february',
                'picnicে':'picnic এ','picnicের':'picnic এর','courseে':'course এ','সেকেন্ড':'second','মিনিটে':'minute এ','লাস্টের':'last এর','পার্টnurseের':'partners',
                'এমপিএস':'mps','ইন্টারভিউ':'interview',

                'ইনস্টাগ্রাম':'instagram','প্রিপারেশন':'preparation','স্পনসর':'sponsor','ডকুমেন্টেশন':'documentation','রিসোর্চ':'resource','গাইডline':'guideline','গ্যালাক্টিক':'galactic',
                'অ্যালুমিনিয়াম':'aluminium','সার্টিফিকেট':'certificate','jobাবদিহির':'জবাবদিহির','serveারে':'server এ','ফটোশপে':'photoshop এ','জেনারেটিভ':'generative','রুলে':'rule এ',
                'চেয়ারম্যানের':'chairman এর','বিলিয়ন':'billion','bat ারির':'battery-র',

                'পিসিবি':'pcb','phoneালাপে':'ফোনালাপে','ওয়েবsiteের':'website এর','moodে':'mood এ','stup':'set up','ওয়ার্ডপ্রেসে':'word press এ','ওয়েবsiteের':'website এর','ইন্টারফেসের':'interface এর',
                'শুটিংয়ে':'shooting এ','সাউথ':'south','এশিয়ান':'asian','রেস্টুরেন্টে':'restaurant এ','ওয়েটার':'Waiter','সিম':'sim','সিমের':'sim এর','ভাইস':'vice','রেক্টর':'rector','সর্বোচ্চ দুই হাজার ৯ষোল':'সর্বোচ্চ দুই হাজার নয়শত ষোল',
                'ইংল্যান্ডের':'england এর','gameে':'game এ','ডেইলি':'daily','রুটিন':'routine','হ্যাবিট':'habit','কনভার্ট':'convert','পিপিপি':'ppp','৫৪টি':'চুয়ান্ন টি','sourceের':'source এর','topিক':'topic','সার্চের':'search এর',
                'টিউটোরিয়ালে':'tutorial এ','থিম':'theme','styleে':'style এ','টিউটোরিয়ালে':'tutorial এ','৯৫পারসেন্ট':'পঁচানব্বই পারসেন্ট',

                'স্যার':'sir','পার্কিং':'parking','কর্নফার্ম':'confirm','কিবোর্ড':'keyboard','ক্রিকেট বোর্ড':'cricket board','ডিগ্রি':'degree','চাকরি নট':'চাকরি not','ভিসা স্পন্সর':'visa sponsor',
                'দুই হাজার দুই৮এক জন':'দুই হাজার দুইশত একাশি জন','useিসির':'ugc-র','কিউআর':'QR','হোয়াটসঅ্যাপ':'whatsapp','computerে':'computer এ','বক্সে':'box এ','অ্যাকাউন্ট':'account ',
                'মেনুতে':'menu তে','ট্যাপ':'tap','হোয়াটসঅ্যাপ':'whatsapp',

                'কুইজ':'quiz','ট্যাবলেট':'tablet','comের':'com এর','wicketের':'wicket এর','mac্সওয়েলকে':'ম্যাক্সওয়েলকে','বুয়েটকে':'Buet কে','ওয়েবsiteে':'website এ','রাjobংশের':'রাজবংশের','লেটার':'letter',
                 '১৪টি':'চৌদ্দ টি','অস্ট্রেলিয়া':'australia','১৮টি':'আঠার টি','অস্ট্রেলিয়ার':'australia-র','ওয়ালে শেয়ার':'wall এ share','সেন্ড করতে হবে':'send করতে হবে','সমsir':'সমস্যার','ক্রপ':'crop',
                'ভাইরাস':'virus','কনসাল':'consult','সফটওয়্যারের':'software এর','ফোনের':'phone এর',

                'আর্toss':'আর্টসের','decemberের':'december এর','preparationের':'preparation এর','মেগা':'mega','wicketে':'wicket এ','officeারদের':'officer দের',
                'ল্যাংগুয়েজ':'language','এপেটাইজার':'appetizer','lineে':'line এ','অডিও-video':'audio-video','অ্যাপটিতে':'app টিতে','সুপ্রিম core্ট':'supreme court','পুলিশের':'police এর',

              'আইআরজিসি-কিউএফ':'IRGC-QF','ওয়াশিংটন':'washington','ই-মেইলের':'e-mail এর','বাংলাlink':'banglalink','হায়ার':'hire','ফর্মটা':'form টা','স্ট্যান্ডার্ড চাটার্ড bank':'Standard Chartered Bank',
                'newsিল্যান্ড':'New Zealand','ইনিংসেও':'inniongs এও','ল্যাবের':'lab এর','৫টি':'পাঁচ টি','অলরাউন্ডারের':'all rounder এর','টেক্সাসে':'texas এ',

                '(বুয়েট)':'Buet','metaনোর':'মেটানোর','webার ডয়চে':'ওয়েবার ডয়চে','novemberে':'november এ','ফ্লাইটের':'flight এর','ফ্লাইটটি':'flight টি','ওয়াশিংটনের':'washington এর',

                'serveিসেসের':'service এর','macডোনাল্ডসের':'McDonalds এর','ওয়াশিংটন':'washington','রিsource':'resource','সিরিয়াসলি':'seriously','developমেন্ট':'development','ওয়ার্ডফেন্সের':'Wordfence এর',
                'ওয়ার্ডফেন্স':'Wordfence','marchের':'march এর','galacticে':'galactic এ','ওয়েবsiteে যুক্ত':'website এ যুক্ত','প্রিমিয়ামে':'premium এ','jumpার':'জাম্পার',

                'Unileverের':'Unilever এর','অপারেটিং সিস্টেমের':'operating system এর','স্প্যানিশ':'spanish','বিজনেস টু বিজনেস':'business to business','Dahak–দশ':'dhaka-দশ','ড্রাইভে':'drive এ',
                'জিমেইলে':'gmail এ','লগইন':'login','মাউসের':'nouse এর','republic পার্টি':'republic party','আইবিএম':'IBM',

                '৪পাঁচ':'পয়তাল্লিশ',' useার নেম':'user name','পাসওয়ার্ড':'password','৩-পাঁচ':'তিন থেকে পাঁচ','লিমিটেড':'limited','ব্রেইন স্টেশন':'braion station','সফটওয়্যার ইঞ্জিনিয়ারকে':'software engineer কে','৫টা':'পাঁচ টা',
                'data সায়েন্স':'data science','মেশিন':'machine','পাইথন':'python','২/এক':'দুই/এক','৬/সাত':'ছয়/সাত','বোলিংয়ে':'bowling এ','teamে':'team এ','রেভিনিউ শেয়ারিং':'revenue sharing',
                'ব্লগ':'blog','বিপিএলের':'BPL এর','কমিটির':'committee-র','২০বার':'বিশ বার','ফাস্ট':'fast','হোয়াটসapp':'whatsapp','and্রয়েড':'android','১৯টি':'উনিশ টি','textileে':'textile এ','mastersে':'masters এ',
                'jobাবদিহি':'জবাবদিহি','অ্যান্টিvirus':'anti-virus','ম্যালওয়্যার':'malaware','পসিবিলিটি':'possibility',

                'আইপিএলের':'IPL এর','codeের':'code এর','টিউটোরিয়াল':'tutorial','৫৩টি':'তিপ্পান্ন টি','১দশটি':'একশ দশ টি','দশ০টির':'একশ টির','officeিয়াল':'official',
                'ম্যালওয়্যারের':'malware এর','ম্যালওয়্যার':'malware','ডেভtoolস':'dev tools','১টি':'একটি','৯টি':'নয়টি','summerের':'summer এর','secondের':'second এর',
                'ওয়ার্ল্ড':'world','কোয়ালিটির':'quality-র',













                }

def rep_bn_en(text):
  for key, value in replace_dict.items():
    text = text.replace(key, value)
  return text

val_csv.Text = val_csv.Text.map(rep_bn_en)

# %%
val_csv.Text = val_csv.Text.map(num_to_word)

# %%
with pd.option_context('display.max_colwidth', 0):
    display(val_csv['Text'][300:325])
# Out:
# 300     অনেকক্ষণ ধরে অনেক বেশি গরম হয়ে থাকা normal নয়। গরম হওয়ার normal কারণের সঙ্গে android phone এ আরেকটি কারণ যোগ হয়। সেটি হলো virus বা ম্যালওয়্যারের কারণে hot হওয়া। iphone এ virus বা ম্যালওয়্যার আক্রমণের ঘটনা বিরল।
# 301    KMQ-572, join direct atact munation ও FMU-139 বোমা ফিউজ। এসব অস্ত্রের আনুমানিক market value  কয়েক লাখ dollar।
# 302    বাসায় লোক পাঠিয়ে যত টাকা পারে নিয়ে যায়।  বাধ্য হয়ে আমাদের একজন partner  আবুল খায়ের company তে চাকরিতে ঢুকে।
# 303    সেটা দেখে সে বিরক্ত হয়ে বলছিল, ‘Unless you are a rock star, we cannot hire you over the phone.’ প্রত্যুত্তরে আমি বলেছিলাম, ‘
# 304    textile বিষয়ে germany তে  সরকারি বা বেসরকারিভাবে গবেষণাও হয়। তাই পড়াশোনা শেষে germany তে এ খাতে কাজ করার ও career build up করার chance রয়েছে।
# 305    এ সমস্যাটা কেন হয় এবং এই সমস্যার সমাধান কি? web development শেখা এবং প্র্যাকটিস করার আসল প্রসেস কি? এই বিষয়গুলো নিয়ে আলোচনা করার চেষ্টা করেছি এখানে।
# 306    এবং মন থেকে খুব trust করতে চাইলাম, একদিন আমি নানাভাই ও ফিলিস্তিনিদের জন্য positively change আনতে পারব।
# 307    আর বাবা assume করতেন, আমি ও মা যেহেতু হিজাব পরি, তাই আমাদের নানা ধরনের কটুকথা comments হতে পারে, যা থেকে তিনি আমাদের save করতে পারবেন না
# 308    আর এর উল্লেখযোগ্য অংশ যুদ্ধের জন্য বরাদ্দ করা হয়েছে। কোথায় কোথায় বরাদ্দগুলো যাচ্ছে, তা নিয়ে ব্যাপক অমিল আছে।’
# 309    নাসার assistant deputy associate administrator ড্যান ইভান্স বলেন, ‘আমরা বৈজ্ঞানিক প্রক্রিয়ার ওপর নির্ভর করে কাজ করি। বিজ্ঞানকে মুক্ত হতে হয়, বিজ্ঞানকে একটি বাস্তব, কঠোর ও logical প্রক্রিয়ার মধ্য দিয়ে যেতে হয়।
# 310    This man along with Kyle Mayers changed the whole dynamics of Barishal’s bowling attack. Mohammad Saifuddin, what a comeback!
# 311    RNA  হচ্ছে বিশেষ ধরনের জেনেটিক অণু, যার মধ্যে প্রোটিন তৈরির নির্দেশনা থাকে। এই গবেষণায় কয়েক লাখ কোষের তথ্য included করা হয়েছে।’
# 312    একজন software engineer হিসেবে আমি: documentation পড়ে নতুন কিছু শেখার চেষ্টা করি। apply  করি, error খাইলে browser dev tools  বা IDE তে debug করি, সমস্যা ধরতে পারলে সেটা fix করে check  করি ঠিক হইছে কিনা।
# 313    একজন ভালো developer হওয়ার দশ টি skill।programming:  minimum একটা programming language এ তোমাকে দক্ষ হতেই হবে।
# 314    মাথার cap টা  খুলেই ছুড়ে মারেন তিনি। সরফরাজের innings এ ছিল নয়টি চারের সঙ্গে একটি ছক্কা।কুলদীপকে নিয়ে দিনের বাকিটা সময় নিরাপদে পার করে captain কে  স্বস্তিই দেন জাদেজা।
# 315    summer এর দিকে july মাসে দেখি বাচ্চাকে কিসে যেন কামড়িয়ে লাল করে ফেলে। জ্বলে, ফুলে যায় আবার চুলকায়ও।
# 316    কারণ: সার্চ দিয়েই second এর মধ্যে ওয়ার্ল্ড class, top কোয়ালিটির resource পেয়ে গেলে আমাদের অবচেতন মনে-- সেগুলার গুরুত্ব কমে যায়। আরে-- আছেই তো, দেখবো তো। এইসব বলে ফেলে রাখি।
# 317    বাংলাদেশের বিপক্ষেই বিশ্বকাপ অভিষেক কোহলি। দুই হাজার এগারো বিশ্বকাপে বাংলাদেশের বিপক্ষে তিরাশি বলে দশ রানের অপরাজিত innings খেলেছিলেন। বাংলাদেশের খেলোয়াড়েরা নিশ্চয়ই এ তথ্য জানেন এবং কোহলিকে থামানোর সব রকম homework নিশ্চয়ই করা হচ্ছে!
# 318    explore  করাকে তুমি enjoy  করো। তাহলে প্যারা নেয়ার কিছুই নাই। তুমি তোমার পছন্দের subject কেউ  ভালো কিছু করতে পারবে। যদি তোমার passion নিয়ে সেই subject এর  পিছনে দীর্ঘ সময় লেগে থাকো।
# 319    ভারতের আন্দোলনরত কৃষকদের নতুন সমাধানের rules  দিল কেন্দ্রীয় সরকার। গতকাল রোববার চতুর্থ দফার বৈঠকে central সরকারের পক্ষে কৃষকদের বলা হয়
# Name: Text, dtype: object

# %%
val_csv.head()
# Out:
#                     id                                               Text
# 0  Recording (527).wav  পরে এসব ভুয়া ছবি, video বা কৃত্রিম কণ্ঠস্বর কা...
# 1  Recording (355).wav  পাকিস্তানের বিপক্ষে টানা চারটি century ওয়ার্না...
# 2  Recording (169).wav  ফজলে এলাহীর বাড়ি কুড়িগ্রামের উলিপুর upazila । ...
# 3  Recording (136).wav  তারা protein এর সেই ‘ক্ষুদ্র কিন্তু important ...
# 4  Recording (938).wav  বিষয়টা খুলে বলব। তারপর উনার office এ যাওয়ার পর...

# %%
import re


def preprocess(text):
  # Regex matching punctuations to remove.
  PUNC = re.compile(r'[`£|¢|Ñ+*/=–—•।!(){};:%\',"“\’<>./?@#$^&*_~‘—॥”‰�￰￰…‽⸘§†‡¶′″]+')
  text = re.sub(PUNC, '', text)
  return text

# %%
train_csv.Text = train_csv.Text.map(preprocess)
val_csv.Text = val_csv.Text.map(preprocess)

# %%
train_csv.head()
# Out:
#    Unnamed: 0                    id  \
# 0        1532  Recording (1533).wav
# 1         628   Recording (629).wav
# 2         693   Recording (694).wav
# 3         705   Recording (706).wav
# 4         497   Recording (498).wav
#
#                                                 Text
# 0  NEVER IN DOUBT Batted all the way with the tai...
# 1  তিনি আল-জাজিরাকে বলেন নয় হাজার পাঁচ শত কোটি do...
# 2  অবশ্য এখন সংখ্যাটি আরও বেড়েছে অধিভুক্ত college...
# 3  কেন্দ্রীয় স্বরাষ্ট্র প্রতিমন্ত্রী নিত্যানন্দ র...
# 4  এ ক্ষেত্রে তাঁরা হামাসের অতীতের বক্তৃতাবয়ানের ...

# %%
val_csv.head()
# Out:
#                     id                                               Text
# 0  Recording (527).wav  পরে এসব ভুয়া ছবি video বা কৃত্রিম কণ্ঠস্বর কাজ...
# 1  Recording (355).wav  পাকিস্তানের বিপক্ষে টানা চারটি century ওয়ার্না...
# 2  Recording (169).wav  ফজলে এলাহীর বাড়ি কুড়িগ্রামের উলিপুর upazila  ব...
# 3  Recording (136).wav  তারা protein এর সেই ক্ষুদ্র কিন্তু important  ...
# 4  Recording (938).wav  বিষয়টা খুলে বলব তারপর উনার office এ যাওয়ার পর ...

# %%
with pd.option_context('display.max_colwidth', 0):
    display(train_csv.head(n=10))
# Out:
#    Unnamed: 0                    id  \
# 0  1532        Recording (1533).wav
# 1  628         Recording (629).wav
# 2  693         Recording (694).wav
# 3  705         Recording (706).wav
# 4  497         Recording (498).wav
# 5  1168        Recording (1169).wav
# 6  490         Recording (491).wav
# 7  1524        Recording (1525).wav
# 8  706         Recording (707).wav
# 9  774         Recording (775).wav
#
#                                                                                                                                                                                    Text
# 0  NEVER IN DOUBT Batted all the way with the tail-enders and took Bangladesh to a very competitive total of 286 runs
# 1  তিনি আল-জাজিরাকে বলেন নয় হাজার পাঁচ শত কোটি dollar এর budget এর মানে হলো যুক্তরাষ্ট্রের কেন্দ্রীয় budget এর পরিমাণ উল্লেখজনক পরিমাণে বেড়েছে
# 2  অবশ্য এখন সংখ্যাটি আরও বেড়েছে অধিভুক্ত college ও মাদ্রাসার শিক্ষার্থীসহ দেশের সরকারিবেসরকারি মিলিয়ে বিশ্ববিদ্যালয়গুলোতে total শিক্ষার্থী সাতচল্লিশ লাখ ছাপ্পান্ন হাজার ৭সাতচল্লিশ জন
# 3  কেন্দ্রীয় স্বরাষ্ট্র প্রতিমন্ত্রী নিত্যানন্দ রাই বৈঠকে ফসলের minimum সহায়ক মূল্য বা MSP-র সঙ্গে কেন্দ্রীয় সরকার শস্য বৈচিত্র্যকে জুড়ে দেওয়ার proposal দেন
# 4  এ ক্ষেত্রে তাঁরা হামাসের অতীতের বক্তৃতাবয়ানের উদ্ধৃতি দিচ্ছেন America এর  প্রতিনিধি পরিষদের আইনপ্রণেতারা স্লোগানটিকে ইহুদিবিদ্বেষী অভিহিত করে আইন প্রণয়ন করেছেন
# 5  অনেকেই দেখলাম GRE RC Section নিয়ে চিন্তিত মনে রাখবেন regular practise ব্যতীত RC section এ improve করা একপ্রকার impossible ব্যাপার
# 6  এমন যুক্তি দিয়ে তিনি press conference এ বলেন ত্রিশ বছর ধরে আমি একই অবস্থান ধরে রেখেছি আমি খুব easy  কথাই বলছি
# 7  some will understand and work on their weaknesses We hope Litton Das will take it on a positive note and come back stronger than ever in the ODI side
# 8  পাঞ্জাব হরিয়ানা ও উত্তর প্রদেশের পশ্চিমাঞ্চলের ধান গম ও আখ চাষের কারণে কৃষিজমির জলস্তর rapidly কমে যাচ্ছে
# 9  congressional কমিটির নেতাদের অনুমোদন পেতে হবে সে ক্ষেত্রে details  এই proposal এ change  আনা হতে পারে

# %%
def add_file_path(path):                                                                   #If mp3_path is "/content/train_mp3s" and path is "file123", the result will be "/content/train_mp3s/file123".
    wav_path = "Speech"
    audio_path = os.path.join(wav_path, path)                                              # create a complete file path by joining the mp3_path and path variables
    #audio_path += '.wav'   #already wave format
    return audio_path

# %%
train_csv.id = train_csv.id.map(add_file_path)
train_csv.head()
# Out:
#    Unnamed: 0                           id  \
# 0        1532  Speech/Recording (1533).wav
# 1         628   Speech/Recording (629).wav
# 2         693   Speech/Recording (694).wav
# 3         705   Speech/Recording (706).wav
# 4         497   Speech/Recording (498).wav
#
#                                                 Text
# 0  NEVER IN DOUBT Batted all the way with the tai...
# 1  তিনি আল-জাজিরাকে বলেন নয় হাজার পাঁচ শত কোটি do...
# 2  অবশ্য এখন সংখ্যাটি আরও বেড়েছে অধিভুক্ত college...
# 3  কেন্দ্রীয় স্বরাষ্ট্র প্রতিমন্ত্রী নিত্যানন্দ র...
# 4  এ ক্ষেত্রে তাঁরা হামাসের অতীতের বক্তৃতাবয়ানের ...

# %%
val_csv.id = val_csv.id.map(add_file_path)
val_csv.head()
# Out:
#                            id  \
# 0  Speech/Recording (527).wav
# 1  Speech/Recording (355).wav
# 2  Speech/Recording (169).wav
# 3  Speech/Recording (136).wav
# 4  Speech/Recording (938).wav
#
#                                                 Text
# 0  পরে এসব ভুয়া ছবি video বা কৃত্রিম কণ্ঠস্বর কাজ...
# 1  পাকিস্তানের বিপক্ষে টানা চারটি century ওয়ার্না...
# 2  ফজলে এলাহীর বাড়ি কুড়িগ্রামের উলিপুর upazila  ব...
# 3  তারা protein এর সেই ক্ষুদ্র কিন্তু important  ...
# 4  বিষয়টা খুলে বলব তারপর উনার office এ যাওয়ার পর ...

# %%
with pd.option_context('display.max_colwidth', 0):
    display(train_csv.head(n=10))
# Out:
#    Unnamed: 0                           id  \
# 0  1532        Speech/Recording (1533).wav
# 1  628         Speech/Recording (629).wav
# 2  693         Speech/Recording (694).wav
# 3  705         Speech/Recording (706).wav
# 4  497         Speech/Recording (498).wav
# 5  1168        Speech/Recording (1169).wav
# 6  490         Speech/Recording (491).wav
# 7  1524        Speech/Recording (1525).wav
# 8  706         Speech/Recording (707).wav
# 9  774         Speech/Recording (775).wav
#
#                                                                                                                                                                                    Text
# 0  NEVER IN DOUBT Batted all the way with the tail-enders and took Bangladesh to a very competitive total of 286 runs
# 1  তিনি আল-জাজিরাকে বলেন নয় হাজার পাঁচ শত কোটি dollar এর budget এর মানে হলো যুক্তরাষ্ট্রের কেন্দ্রীয় budget এর পরিমাণ উল্লেখজনক পরিমাণে বেড়েছে
# 2  অবশ্য এখন সংখ্যাটি আরও বেড়েছে অধিভুক্ত college ও মাদ্রাসার শিক্ষার্থীসহ দেশের সরকারিবেসরকারি মিলিয়ে বিশ্ববিদ্যালয়গুলোতে total শিক্ষার্থী সাতচল্লিশ লাখ ছাপ্পান্ন হাজার ৭সাতচল্লিশ জন
# 3  কেন্দ্রীয় স্বরাষ্ট্র প্রতিমন্ত্রী নিত্যানন্দ রাই বৈঠকে ফসলের minimum সহায়ক মূল্য বা MSP-র সঙ্গে কেন্দ্রীয় সরকার শস্য বৈচিত্র্যকে জুড়ে দেওয়ার proposal দেন
# 4  এ ক্ষেত্রে তাঁরা হামাসের অতীতের বক্তৃতাবয়ানের উদ্ধৃতি দিচ্ছেন America এর  প্রতিনিধি পরিষদের আইনপ্রণেতারা স্লোগানটিকে ইহুদিবিদ্বেষী অভিহিত করে আইন প্রণয়ন করেছেন
# 5  অনেকেই দেখলাম GRE RC Section নিয়ে চিন্তিত মনে রাখবেন regular practise ব্যতীত RC section এ improve করা একপ্রকার impossible ব্যাপার
# 6  এমন যুক্তি দিয়ে তিনি press conference এ বলেন ত্রিশ বছর ধরে আমি একই অবস্থান ধরে রেখেছি আমি খুব easy  কথাই বলছি
# 7  some will understand and work on their weaknesses We hope Litton Das will take it on a positive note and come back stronger than ever in the ODI side
# 8  পাঞ্জাব হরিয়ানা ও উত্তর প্রদেশের পশ্চিমাঞ্চলের ধান গম ও আখ চাষের কারণে কৃষিজমির জলস্তর rapidly কমে যাচ্ছে
# 9  congressional কমিটির নেতাদের অনুমোদন পেতে হবে সে ক্ষেত্রে details  এই proposal এ change  আনা হতে পারে

# %%
# Rename the 'id' to 'path' by changing the original dataframe (inplace=True)
train_csv.rename(columns={'id': 'path'}, inplace=True)
val_csv.rename(columns={'id': 'path'}, inplace=True)

train_csv.head()
# Out:
#    Unnamed: 0                         path  \
# 0        1532  Speech/Recording (1533).wav
# 1         628   Speech/Recording (629).wav
# 2         693   Speech/Recording (694).wav
# 3         705   Speech/Recording (706).wav
# 4         497   Speech/Recording (498).wav
#
#                                                 Text
# 0  NEVER IN DOUBT Batted all the way with the tai...
# 1  তিনি আল-জাজিরাকে বলেন নয় হাজার পাঁচ শত কোটি do...
# 2  অবশ্য এখন সংখ্যাটি আরও বেড়েছে অধিভুক্ত college...
# 3  কেন্দ্রীয় স্বরাষ্ট্র প্রতিমন্ত্রী নিত্যানন্দ র...
# 4  এ ক্ষেত্রে তাঁরা হামাসের অতীতের বক্তৃতাবয়ানের ...

# %%
val_csv.head()
# Out:
#                          path  \
# 0  Speech/Recording (527).wav
# 1  Speech/Recording (355).wav
# 2  Speech/Recording (169).wav
# 3  Speech/Recording (136).wav
# 4  Speech/Recording (938).wav
#
#                                                 Text
# 0  পরে এসব ভুয়া ছবি video বা কৃত্রিম কণ্ঠস্বর কাজ...
# 1  পাকিস্তানের বিপক্ষে টানা চারটি century ওয়ার্না...
# 2  ফজলে এলাহীর বাড়ি কুড়িগ্রামের উলিপুর upazila  ব...
# 3  তারা protein এর সেই ক্ষুদ্র কিন্তু important  ...
# 4  বিষয়টা খুলে বলব তারপর উনার office এ যাওয়ার পর ...

# %%
# def extract_all_chars(batch):
#     # print(batch)
#     all_text = " ".join(batch["Text"])
#     vocab = list(set(all_text))
#     return {"vocab": [vocab], "all_text": [all_text]}

# %%
# train_csv_d = Dataset.from_pandas(train_csv)
# train_csv_d

# %%
# val_csv_d = Dataset.from_pandas(val_csv)
# val_csv_d

# %%
# vocab_df = train_csv_d.map(extract_all_chars)

# %%
# len(vocab_df["vocab"])

# %%
# vocab_df = val_csv_d.map(extract_all_chars)

# %%
# len(vocab_df["vocab"])

# %%
# def create_vocab(vocab_df):
#     v_character_list = []
#     for v_df in vocab_df["vocab"]:
#     #     print(v_train)
#         for v_chr in v_df[0]:
#             if v_chr not in v_character_list:
#                 v_character_list.append(v_chr)
#     return v_character_list

# %%
# df_vocab = create_vocab(vocab_df)

# %%
# print(df_vocab)

# %%
# vocab_dict = {v: k for k, v in enumerate(df_vocab)}   # k is index and V is vocabulary or character
# print(vocab_dict)

# %%
# model_path = "bangla-speech-processing/BanglaASR"


# feature_extractor = WhisperFeatureExtractor.from_pretrained(model_path)
# tokenizer = WhisperTokenizer.from_pretrained(model_path)
# processor = WhisperProcessor.from_pretrained(model_path)

# %%
#model_path = "openai/whisper-medium"
model_path = "openai/whisper-small"
# model_path = "openai/whisper-large-v3"
#model_path = "hishab/hishab_bn_fastconformer"


feature_extractor = WhisperFeatureExtractor.from_pretrained(model_path)
tokenizer = WhisperTokenizer.from_pretrained(model_path)
processor = WhisperProcessor.from_pretrained(model_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# print(f"The total duration of audio files is {(total_duration_train+total_duration_val)/3600} hours")

# %%
#task-1 are given....

# %%
#max token from train_csv

max_token_length = 0
max_idx_list = []
for i in range(len(train_csv)):
    input_str = train_csv['Text'].iloc[i]
    labels = tokenizer(input_str).input_ids
    input_str_token = tokenizer.convert_ids_to_tokens(labels)
    if len(input_str_token)>max_token_length:
        max_token_length = len(input_str_token)
        idx = i
    if len(input_str_token)>448:
        max_idx_list.append(i)
print(f"The max_token_length is: {max_token_length}")
print(f"The max_token_length index is: {idx}")
print(f"The max index list are: {max_idx_list}")
# Out:
# The max_token_length is: 510
# The max_token_length index is: 1267
# The max index list are: [97, 193, 200, 213, 222, 295, 367, 489, 671, 837, 841, 946, 992, 1121, 1184, 1267]

# %%
#Remove the row whose token>448 and get new train set

# %%
new_train_df = train_csv.drop(max_idx_list)
print(len(new_train_df))
# Out:
# 1264

# %%
#max token for val_csv

max_token_length = 0
max_idx_list = []
for i in range(len(val_csv)):
    input_str = val_csv['Text'].iloc[i]
    labels = tokenizer(input_str).input_ids
    input_str_token = tokenizer.convert_ids_to_tokens(labels)
    if len(input_str_token)>max_token_length:
        max_token_length = len(input_str_token)
        idx = i
    if len(input_str_token)>448:
        max_idx_list.append(i)
print(f"The max_token_length is: {max_token_length}")
print(f"The max_token_length index is: {idx}")
print(f"The max index list are: {max_idx_list}")
# Out:
# The max_token_length is: 583
# The max_token_length index is: 234
# The max index list are: [1, 50, 172, 192, 234, 292]

# %%
new_val_df = val_csv.drop(max_idx_list)
print(len(new_val_df))
# Out:
# 314

# %%
def each_file_duration(file_path):
    try:
        audio_data, sample_rate = librosa.load(file_path)
        duration = librosa.get_duration(y=audio_data, sr=sample_rate)
        return duration
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return 0.0

def find_max_duration_file(dataset, path_column='path'):
    max_duration = 0.0
    max_duration_file = None

    for index, row in dataset.iterrows():
        file_path = row[path_column]
        if os.path.isfile(file_path):
            duration = each_file_duration(file_path)
            if duration > max_duration:
                max_duration = duration
                max_duration_file = file_path
        else:
            print(f"File not found: {file_path}")

    return max_duration_file, max_duration

max_duration_file, max_duration = find_max_duration_file(new_train_df)

print(f"The audio file with the maximum duration is: {max_duration_file}")
print(f"Its duration is: {max_duration:.2f} seconds")
# Out:
# The audio file with the maximum duration is: Speech/Recording (326).wav
# Its duration is: 31.37 seconds

# %%
#Find the text whose duration>30 second and their indices

# %%
def each_file_duration(file_path):
    try:
        audio_data, sample_rate = librosa.load(file_path)
        duration = librosa.get_duration(y=audio_data, sr=sample_rate)
        return duration
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return 0.0

def find_long_duration_indices(dataset, path_column='path', min_duration=30):
    voice_idx_list = []

    for index, row in dataset.iterrows():
        file_path = row[path_column]
        if os.path.isfile(file_path):
            duration = each_file_duration(file_path)
            if duration > min_duration:
                voice_idx_list.append(index)

        else:
            print(f"File not found: {file_path}")
    return voice_idx_list

long_duration = find_long_duration_indices(new_train_df, min_duration=30)

print(long_duration)
# Out:
# [328]

# %%
#remove the row of index 328
new_train_df_2 = new_train_df[new_train_df['path'] != 'Speech/Recording (326).wav']

# %%
print(len(new_train_df_2))
# Out:
# 1263

# %%
#play and get the duration of that max length audio (val)

# %%
def each_file_duration(file_path):
    try:
        audio_data, sample_rate = librosa.load(file_path)
        duration = librosa.get_duration(y=audio_data, sr=sample_rate)
        return duration
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return 0.0

def find_max_duration_file(dataset, path_column='path'):
    max_duration = 0.0
    max_duration_file = None

    for index, row in dataset.iterrows():
        file_path = row[path_column]
        if os.path.isfile(file_path):
            duration = each_file_duration(file_path)
            if duration > max_duration:
                max_duration = duration
                max_duration_file = file_path
        else:
            print(f"File not found: {file_path}")

    return max_duration_file, max_duration

max_duration_file, max_duration = find_max_duration_file(new_val_df)

print(f"The audio file with the maximum duration is: {max_duration_file}")
print(f"Its duration is: {max_duration:.2f} seconds")
# Out:
# The audio file with the maximum duration is: Speech/Recording (1293).wav
# Its duration is: 30.28 seconds

# %%
#Find the text whose duration>30 second and their indices

# %%
def each_file_duration(file_path):
    try:
        audio_data, sample_rate = librosa.load(file_path)
        duration = librosa.get_duration(y=audio_data, sr=sample_rate)
        return duration
    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return 0.0

def find_long_duration_indices(dataset, path_column='path', min_duration=30):
    voice_idx_list = []

    for index, row in dataset.iterrows():
        file_path = row[path_column]
        if os.path.isfile(file_path):
            duration = each_file_duration(file_path)
            if duration > min_duration:
                voice_idx_list.append(index)

        else:
            print(f"File not found: {file_path}")
    return voice_idx_list

long_duration = find_long_duration_indices(new_val_df, min_duration=30)

print(long_duration)
# Out:
# [70, 236]

# %%
#remove the row of index 328
new_val_df_2 = new_val_df[new_val_df['path'] != 'Speech/Recording (1293).wav']

# %%
print(len(new_val_df_2))
# Out:
# 313

# %%
#prepared

# %%
train_csv_d = Dataset.from_pandas(new_train_df_2)
train_csv_d
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'path', 'Text', '__index_level_0__'],
#     num_rows: 1263
# })

# %%
remove_index_train_df = train_csv_d.to_pandas().drop('__index_level_0__', axis=1)
remove_index_train_df
# Out:
#       Unnamed: 0                         path  \
# 0           1532  Speech/Recording (1533).wav
# 1            628   Speech/Recording (629).wav
# 2            693   Speech/Recording (694).wav
# 3            705   Speech/Recording (706).wav
# 4            497   Speech/Recording (498).wav
# ...          ...                          ...
# 1258        1130  Speech/Recording (1131).wav
# 1259        1294  Speech/Recording (1295).wav
# 1260         860   Speech/Recording (861).wav
# 1261        1459  Speech/Recording (1460).wav
# 1262        1126  Speech/Recording (1127).wav
#
#                                                    Text
# 0     NEVER IN DOUBT Batted all the way with the tai...
# 1     তিনি আল-জাজিরাকে বলেন নয় হাজার পাঁচ শত কোটি do...
# 2     অবশ্য এখন সংখ্যাটি আরও বেড়েছে অধিভুক্ত college...
# 3     কেন্দ্রীয় স্বরাষ্ট্র প্রতিমন্ত্রী নিত্যানন্দ র...
# 4     এ ক্ষেত্রে তাঁরা হামাসের অতীতের বক্তৃতাবয়ানের ...
# ...                                                 ...
# 1258  আমার বাড়িওয়ালাকে বলছিলাম তার office time এর সা...
# 1259   bonus Scott Wu এবং তার ভাই Neal Wu দুই ভাই ই ...
# 1260  বিশেষ করে আমার নানা যখন জাতিসংঘের দেওয়া tent য...
# 1261  Mustafizur Rahman played for Delhi Capitals Su...
# 1262  এই দুই পায়ের উপরে ভর করে দৈনিক পঞ্চাশ minutes ...
#
# [1263 rows x 3 columns]

# %%
new_train_csv_d = Dataset.from_pandas(remove_index_train_df)
new_train_csv_d
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'path', 'Text'],
#     num_rows: 1263
# })

# %%
val_csv_d = Dataset.from_pandas(new_val_df_2)
val_csv_d
# Out:
# Dataset({
#     features: ['path', 'Text', '__index_level_0__'],
#     num_rows: 313
# })

# %%
remove_index_val_df = val_csv_d.to_pandas().drop('__index_level_0__', axis=1)
remove_index_val_df
# Out:
#                             path  \
# 0     Speech/Recording (527).wav
# 1     Speech/Recording (169).wav
# 2     Speech/Recording (136).wav
# 3     Speech/Recording (938).wav
# 4    Speech/Recording (1545).wav
# ..                           ...
# 308  Speech/Recording (1075).wav
# 309  Speech/Recording (1316).wav
# 310   Speech/Recording (384).wav
# 311  Speech/Recording (1274).wav
# 312   Speech/Recording (701).wav
#
#                                                   Text
# 0    পরে এসব ভুয়া ছবি video বা কৃত্রিম কণ্ঠস্বর কাজ...
# 1    ফজলে এলাহীর বাড়ি কুড়িগ্রামের উলিপুর upazila  ব...
# 2    তারা protein এর সেই ক্ষুদ্র কিন্তু important  ...
# 3    বিষয়টা খুলে বলব তারপর উনার office এ যাওয়ার পর ...
# 4    Tamim Iqbal to bat at 1 downTamim has not open...
# ..                                                 ...
# 308  summer এর দিকে july মাসে দেখি বাচ্চাকে কিসে যে...
# 309  কারণ সার্চ দিয়েই second এর মধ্যে ওয়ার্ল্ড clas...
# 310  বাংলাদেশের বিপক্ষেই বিশ্বকাপ অভিষেক কোহলি দুই ...
# 311  explore  করাকে তুমি enjoy  করো তাহলে প্যারা নে...
# 312  ভারতের আন্দোলনরত কৃষকদের নতুন সমাধানের rules  ...
#
# [313 rows x 2 columns]

# %%
new_val_csv_d = Dataset.from_pandas(remove_index_val_df)
new_val_csv_d
# Out:
# Dataset({
#     features: ['path', 'Text'],
#     num_rows: 313
# })

# %%
def prepare_dataset(batch):
    MAX_DURATION_IN_SECONDS = 30
    max_input_length = MAX_DURATION_IN_SECONDS * 16000
    speech_array, sampling_rate = torchaudio.load(batch["path"], format="wav")
    array = speech_array[0].numpy()
    batch["array"] = librosa.resample(np.asarray(array), orig_sr=sampling_rate, target_sr=16000)
    batch["sampling_rate"] = 16000
    batch["input_features"] = feature_extractor(batch["array"],
                                                sampling_rate=batch["sampling_rate"],
                                                max_length=max_input_length).input_features[0]
    batch["input_length"] = len(batch["array"]) / batch["sampling_rate"]
    batch["labels"] = tokenizer(batch["Text"],
                                truncation=True,
                                padding="max_length",
                                max_length=448).input_ids
    return batch

# %%
train_dataset = new_train_csv_d.map(prepare_dataset)
val_dataset = new_val_csv_d.map(prepare_dataset)
# Out:
# Map:   0%|          | 0/1263 [00:00<?, ? examples/s]
# Map:   0%|          | 0/313 [00:00<?, ? examples/s]

# %%
# max_input_length = 30.0


# def is_audio_in_length_range(length):
#     return length < max_input_length

# %%
train_dataset
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'path', 'Text', 'array', 'sampling_rate', 'input_features', 'input_length', 'labels'],
#     num_rows: 1263
# })

# %%
# train_dataset = train_dataset.filter(
#     is_audio_in_length_range,
#     input_columns=["input_length"],
# )

# %%
# val_dataset = val_dataset.filter(
#     is_audio_in_length_range,
#     input_columns=["input_length"],
# )

# %%
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [{"input_features": feature["input_features"]} for feature in features]
        #batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")
        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)
        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch



data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
metric = evaluate.load("wer")

def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = tokenizer.batch_decode(label_ids, skip_special_tokens=True)

    wer = 100 * metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
model = WhisperForConditionalGeneration.from_pretrained(model_path)

model.config.forced_decoder_ids = None
model.config.suppress_tokens = []

# %%
from functools import partial

# disable cache during training since it's incompatible with gradient checkpointing
model.config.use_cache = False

# set language and task for generation and re-enable cache
model.generate = partial(
    model.generate, language="Bengali", task="transcribe", use_cache=True
)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="./whisper-small",              # change to a repo name of your choice
    per_device_train_batch_size=4,               #16
    gradient_accumulation_steps=2,  #1                # increase by 2x for every 2x decrease in batch size
    learning_rate=1e-5,
    warmup_steps=500,
    max_steps=12000,
    gradient_checkpointing=False,
    fp16=False, #True
    evaluation_strategy="steps",
    save_strategy="steps",
    save_total_limit=2,
    per_device_eval_batch_size=4,
    predict_with_generate=True,
    generation_max_length=225,
    save_steps=500,
    eval_steps=500,
    logging_steps=25,
    # report_to=["tensorboard"],
    load_best_model_at_end=True,
    metric_for_best_model="wer",
    greater_is_better=False,
    push_to_hub=False,

)

# %%
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
    tokenizer=processor.feature_extractor,
)

processor.save_pretrained(training_args.output_dir)
# Out:
# max_steps is given, it will override any value given in num_train_epochs
# []

# %%
trainer.train()
